# %%
import os
os.environ['CUDA_VISIBLE_DEVICES'] = '0'
os.environ["XLA_PYTHON_CLIENT_PREALLOCATE"]="false"

import pathlib
import glob
from copy import deepcopy

import tqdm
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

import jax
import jax.numpy as jnp
import equinox as eqx

# %%
from mc2.utils.data_inspection import (
    get_available_material_names,
    get_file_overview,
    load_and_process_single_from_full_file_overview
)
from mc2.data_management import FrequencySet, MaterialSet, DataSet

# %% [markdown]
# ## load data from pickle:

# %%
dataset = DataSet.load_from_file(pathlib.Path("../../data/processed") / "ten_mat_data.pickle")

## deleting N49 from dataset for now, since the data is incomplete
# 50 kHz and 80 kHz are missing
# 320 kHz has no data at 25 degrees

available_materials = deepcopy(dataset.material_names)
print(available_materials)
print(len(available_materials))

available_materials.remove("N49")
print(available_materials)
print(len(available_materials))


dataset = dataset.filter_materials(available_materials)
assert dataset.material_names == available_materials
# Out:
# ['3C90', '3C94', '3E6', '3F4', '77', '78', 'N27', 'N30', 'N49', 'N87']
# 10
# ['3C90', '3C94', '3E6', '3F4', '77', '78', 'N27', 'N30', 'N87']
# 9

# %%
data_3C90 = dataset.filter_materials(material_names="3C90")
data_3C90_25_C = data_3C90.filter_temperatures([25])

PLOT_HYSTERESIS = True
PLOT_SWITCHING_EVENTS = True
PLOT_RIPPLE_HIST = False

for frequency_set in data_3C90_25_C.material_sets[0].frequency_sets:
    print(frequency_set)
    for i in range(0, frequency_set.H.shape[0], 100):
        h, b, f = frequency_set.H[i], frequency_set.B[i], frequency_set.frequency
        if PLOT_HYSTERESIS:
            plt.plot(h, b)

        # postive, if db/dt is positive and 
        bool_ascending = np.roll(b, shift=1) - b
        # Get the sign of each element
        signs = np.sign(bool_ascending)
        # Compute differences between adjacent signs
        sign_changes = np.diff(signs, append=signs[0])  # append the first value to keep the same dimension


        # Count non-zero sign changes
        # always 198 ...
        count_sign_changes = np.count_nonzero(sign_changes)
        print("\nSign changes of db/dt:")
        print(f"No. of 1: {count_sign_changes} (sign changes)")
        print(f"No. of 0: {len(sign_changes)-count_sign_changes}\n")


        # Carrier signal with "slow" frequency
        print("Carrier signal:")
        T_carrier = 1 / f * count_sign_changes / 2
        print(f"{T_carrier = }")
        f_carrier = 1 / T_carrier
        print(f"{f_carrier = }")
        print(f"hmax = {float(max(h))}")
        print(f"bmax = {float(max(b))}\n")


        # Find the amplitude:
        mask = (sign_changes != 0).astype(int)  # this is 1, if there is the beginning or the end of a "fast" cycle

        b_HF_amplitudes = np.where(mask, b, 0)

        b_HF_amplitudes_filtered = b_HF_amplitudes[b_HF_amplitudes != 0]
        b_ripple = abs(np.roll(b_HF_amplitudes_filtered, shift=-1) - b_HF_amplitudes_filtered)


        if PLOT_RIPPLE_HIST:
            # Overimposed "fast" ripple
            print("Overimposed ripple:")
            plt.hist(b_ripple)

        if PLOT_SWITCHING_EVENTS:
            plt.plot(h, mask/10, label="switching events") # db/dt sign changes 

        plt.legend()
        plt.show()
# Out:
# FrequencySet(
#   material_name='3C90',
#   frequency=50000.0,
#   H=f32[235,32016],
#   B=f32[235,32016],
#   T=f32[235]
# )
#
# Sign changes of db/dt:
# No. of 1: 198 (sign changes)
# No. of 0: 31818
#
# Carrier signal:
# T_carrier = 0.00198
# f_carrier = 505.0505050505051
# hmax = 142.93081665039062
# bmax = 0.4057658016681671
#
# Overimposed ripple:
# Sign changes of db/dt:
# No. of 1: 198 (sign changes)
# No. of 0: 31818
#
# Carrier signal:
# T_carrier = 0.00198
# f_carrier = 505.0505050505051
# hmax = 651.5406494140625
# bmax = 0.4727984666824341
#
# Overimposed ripple:
# Sign changes of db/dt:
# No. of 1: 198 (sign changes)
# No. of 0: 31818
#
# Carrier signal:
# T_carrier = 0.00198
# f_carrier = 505.0505050505051
# hmax = 651.5406494140625
# bmax = 0.47340524196624756
#
# Overimposed ripple:
# FrequencySet(
#   material_name='3C90',
#   frequency=80000.0,
#   H=f32[524,20016],
#   B=f32[524,20016],
#   T=f32[524]
# )
#
# Sign changes of db/dt:
# No. of 1: 198 (sign changes)
# No. of 0: 19818
#
# Carrier signal:
# T_carrier = 0.0012375
# f_carrier = 808.080808080808
# hmax = 49.08795166015625
# bmax = 0.24746325612068176
#
# Overimposed ripple:
# Sign changes of db/dt:
# No. of 1: 198 (sign changes)
# No. of 0: 19818
#
# Carrier signal:
# T_carrier = 0.0012375
# f_carrier = 808.080808080808
# hmax = 54.187068939208984
# bmax = 0.2816806733608246
#
# Overimposed ripple:
# Sign changes of db/dt:
# No. of 1: 198 (sign changes)
# No. of 0: 19818
#
# Carrier signal:
# T_carrier = 0.0012375
# f_carrier = 808.080808080808
# hmax = 46.977569580078125
# bmax = 0.236465185880661
#
# Overimposed ripple:
# Sign changes of db/dt:
# No. of 1: 198 (sign changes)
# No. of 0: 19818
#
# Carrier signal:
# T_carrier = 0.0012375
# f_carrier = 808.080808080808
# hmax = 235.09251403808594
# bmax = 0.43695172667503357
#
# Overimposed ripple:
# Sign changes of db/dt:
# No. of 1: 198 (sign changes)
# No. of 0: 19818
#
# Carrier signal:
# T_carrier = 0.0012375
# f_carrier = 808.080808080808
# hmax = 37.64433670043945
# bmax = 0.1938190758228302
#
# Overimposed ripple:
# Sign changes of db/dt:
# No. of 1: 198 (sign changes)
# No. of 0: 19818
#
# Carrier signal:
# T_carrier = 0.0012375
# f_carrier = 808.080808080808
# hmax = 65.24381256103516
# bmax = 0.32168278098106384
#
# Overimposed ripple:
# FrequencySet(
#   material_name='3C90',
#   frequency=125000.0,
#   H=f32[947,12816],
#   B=f32[947,12816],
#   T=f32[947]
# )
#
# Sign changes of db/dt:
# No. of 1: 198 (sign changes)
# No. of 0: 12618
#
# Carrier signal:
# T_carrier = 0.000792
# f_carrier = 1262.6262626262628
# hmax = 32.081424713134766
# bmax = 0.15389801561832428
#
# Overimposed ripple:
# Sign changes of db/dt:
# No. of 1: 198 (sign changes)
# No. of 0: 12618
#
# Carrier signal:
# T_carrier = 0.000792
# f_carrier = 1262.6262626262628
# hmax = 52.24845886230469
# bmax = 0.2793959975242615
#
# Overimposed ripple:
# Sign changes of db/dt:
# No. of 1: 198 (sign changes)
# No. of 0: 12618
#
# Carrier signal:
# T_carrier = 0.000792
# f_carrier = 1262.6262626262628
# hmax = 29.495195388793945
# bmax = 0.14153353869915009
#
# Overimposed ripple:
# Sign changes of db/dt:
# No. of 1: 198 (sign changes)
# No. of 0: 12618
#
# Carrier signal:
# T_carrier = 0.000792
# f_carrier = 1262.6262626262628
# hmax = 48.34095001220703
# bmax = 0.241499662399292
#
# Overimposed ripple:
# Sign changes of db/dt:
# No. of 1: 198 (sign changes)
# No. of 0: 12618
#
# Carrier signal:
# T_carrier = 0.000792
# f_carrier = 1262.6262626262628
# hmax = 46.97809982299805
# bmax = 0.24656179547309875
#
# Overimposed ripple:
# Sign changes of db/dt:
# No. of 1: 198 (sign changes)
# No. of 0: 12618
#
# Carrier signal:
# T_carrier = 0.000792
# f_carrier = 1262.6262626262628
# hmax = 651.5406494140625
# bmax = 0.4896628260612488
#
# Overimposed ripple:
# Sign changes of db/dt:
# No. of 1: 198 (sign changes)
# No. of 0: 12618
#
# Carrier signal:
# T_carrier = 0.000792
# f_carrier = 1262.6262626262628
# hmax = 63.71090316772461
# bmax = 0.32995375990867615
#
# Overimposed ripple:
# Sign changes of db/dt:
# No. of 1: 198 (sign changes)
# No. of 0: 12618
#
# Carrier signal:
# T_carrier = 0.000792
# f_carrier = 1262.6262626262628
# hmax = 40.983787536621094
# bmax = 0.2152441293001175
#
# Overimposed ripple:
# Sign changes of db/dt:
# No. of 1: 198 (sign changes)
# No. of 0: 12618
#
# Carrier signal:
# T_carrier = 0.000792
# f_carrier = 1262.6262626262628
# hmax = 104.84326934814453
# bmax = 0.38797175884246826
#
# Overimposed ripple:
# Sign changes of db/dt:
# No. of 1: 198 (sign changes)
# No. of 0: 12618
#
# Carrier signal:
# T_carrier = 0.000792
# f_carrier = 1262.6262626262628
# hmax = 61.968013763427734
# bmax = 0.30099281668663025
#
# Overimposed ripple:
# FrequencySet(
#   material_name='3C90',
#   frequency=200000.0,
#   H=f32[1293,8015],
#   B=f32[1293,8015],
#   T=f32[1293]
# )
#
# Sign changes of db/dt:
# No. of 1: 198 (sign changes)
# No. of 0: 7817
#
# Carrier signal:
# T_carrier = 0.000495
# f_carrier = 2020.2020202020203
# hmax = 23.72798728942871
# bmax = 0.10847550630569458
#
# Overimposed ripple:
# Sign changes of db/dt:
# No. of 1: 198 (sign changes)
# No. of 0: 7817
#
# Carrier signal:
# T_carrier = 0.000495
# f_carrier = 2020.2020202020203
# hmax = 36.934814453125
# bmax = 0.18361136317253113
#
# Overimposed ripple:
# Sign changes of db/dt:
# No. of 1: 198 (sign changes)
# No. of 0: 7817
#
# Carrier signal:
# T_carrier = 0.000495
# f_carrier = 2020.2020202020203
# hmax = 24.840713500976562
# bmax = 0.12535405158996582
#
# Overimposed ripple:
# Sign changes of db/dt:
# No. of 1: 198 (sign changes)
# No. of 0: 7817
#
# Carrier signal:
# T_carrier = 0.000495
# f_carrier = 2020.2020202020203
# hmax = 33.03546905517578
# bmax = 0.15789596736431122
#
# Overimposed ripple:
# Sign changes of db/dt:
# No. of 1: 198 (sign changes)
# No. of 0: 7817
#
# Carrier signal:
# T_carrier = 0.000495
# f_carrier = 2020.2020202020203
# hmax = 47.6143798828125
# bmax = 0.2513229250907898
#
# Overimposed ripple:
# Sign changes of db/dt:
# No. of 1: 198 (sign changes)
# No. of 0: 7817
#
# Carrier signal:
# T_carrier = 0.000495
# f_carrier = 2020.2020202020203
# hmax = 64.40287780761719
# bmax = 0.32202449440956116
#
# Overimposed ripple:
# Sign changes of db/dt:
# No. of 1: 198 (sign changes)
# No. of 0: 7817
#
# Carrier signal:
# T_carrier = 0.000495
# f_carrier = 2020.2020202020203
# hmax = 49.18003463745117
# bmax = 0.2646009922027588
#
# Overimposed ripple:
# Sign changes of db/dt:
# No. of 1: 198 (sign changes)
# No. of 0: 7817
#
# Carrier signal:
# T_carrier = 0.000495
# f_carrier = 2020.2020202020203
# hmax = 18.944419860839844
# bmax = 0.08335511386394501
#
# Overimposed ripple:
# Sign changes of db/dt:
# No. of 1: 198 (sign changes)
# No. of 0: 7817
#
# Carrier signal:
# T_carrier = 0.000495
# f_carrier = 2020.2020202020203
# hmax = 651.531494140625
# bmax = 0.48737016320228577
#
# Overimposed ripple:
# Sign changes of db/dt:
# No. of 1: 198 (sign changes)
# No. of 0: 7817
#
# Carrier signal:
# T_carrier = 0.000495
# f_carrier = 2020.2020202020203
# hmax = 63.44255447387695
# bmax = 0.31939518451690674
#
# Overimposed ripple:
# Sign changes of db/dt:
# No. of 1: 198 (sign changes)
# No. of 0: 7817
#
# Carrier signal:
# T_carrier = 0.000495
# f_carrier = 2020.2020202020203
# hmax = 28.87019157409668
# bmax = 0.13783589005470276
#
# Overimposed ripple:
# Sign changes of db/dt:
# No. of 1: 198 (sign changes)
# No. of 0: 7817
#
# Carrier signal:
# T_carrier = 0.000495
# f_carrier = 2020.2020202020203
# hmax = 37.31690216064453
# bmax = 0.19092334806919098
#
# Overimposed ripple:
# Sign changes of db/dt:
# No. of 1: 198 (sign changes)
# No. of 0: 7817
#
# Carrier signal:
# T_carrier = 0.000495
# f_carrier = 2020.2020202020203
# hmax = 144.35630798339844
# bmax = 0.43262922763824463
#
# Overimposed ripple:
# FrequencySet(
#   material_name='3C90',
#   frequency=320000.0,
#   H=f32[1300,5008],
#   B=f32[1300,5008],
#   T=f32[1300]
# )
#
# Sign changes of db/dt:
# No. of 1: 198 (sign changes)
# No. of 0: 4810
#
# Carrier signal:
# T_carrier = 0.000309375
# f_carrier = 3232.323232323232
# hmax = 12.527809143066406
# bmax = 0.048140622675418854
#
# Overimposed ripple:
# Sign changes of db/dt:
# No. of 1: 198 (sign changes)
# No. of 0: 4810
#
# Carrier signal:
# T_carrier = 0.000309375
# f_carrier = 3232.323232323232
# hmax = 39.27131652832031
# bmax = 0.18957370519638062
#
# Overimposed ripple:
# Sign changes of db/dt:
# No. of 1: 198 (sign changes)
# No. of 0: 4810
#
# Carrier signal:
# T_carrier = 0.000309375
# f_carrier = 3232.323232323232
# hmax = 25.943201065063477
# bmax = 0.11677403748035431
#
# Overimposed ripple:
# Sign changes of db/dt:
# No. of 1: 198 (sign changes)
# No. of 0: 4810
#
# Carrier signal:
# T_carrier = 0.000309375
# f_carrier = 3232.323232323232
# hmax = 15.369840621948242
# bmax = 0.06420757621526718
#
# Overimposed ripple:
# Sign changes of db/dt:
# No. of 1: 198 (sign changes)
# No. of 0: 4810
#
# Carrier signal:
# T_carrier = 0.000309375
# f_carrier = 3232.323232323232
# hmax = 31.6622314453125
# bmax = 0.14851698279380798
#
# Overimposed ripple:
# Sign changes of db/dt:
# No. of 1: 198 (sign changes)
# No. of 0: 4810
#
# Carrier signal:
# T_carrier = 0.000309375
# f_carrier = 3232.323232323232
# hmax = 25.9739990234375
# bmax = 0.1138298511505127
#
# Overimposed ripple:
# Sign changes of db/dt:
# No. of 1: 198 (sign changes)
# No. of 0: 4810
#
# Carrier signal:
# T_carrier = 0.000309375
# f_carrier = 3232.323232323232
# hmax = 21.046646118164062
# bmax = 0.09090268611907959
#
# Overimposed ripple:
# Sign changes of db/dt:
# No. of 1: 198 (sign changes)
# No. of 0: 4810
#
# Carrier signal:
# T_carrier = 0.000309375
# f_carrier = 3232.323232323232
# hmax = 35.21504592895508
# bmax = 0.1659521609544754
#
# Overimposed ripple:
# Sign changes of db/dt:
# No. of 1: 198 (sign changes)
# No. of 0: 4810
#
# Carrier signal:
# T_carrier = 0.000309375
# f_carrier = 3232.323232323232
# hmax = 29.258665084838867
# bmax = 0.1334763616323471
#
# Overimposed ripple:
# Sign changes of db/dt:
# No. of 1: 198 (sign changes)
# No. of 0: 4810
#
# Carrier signal:
# T_carrier = 0.000309375
# f_carrier = 3232.323232323232
# hmax = 22.045385360717773
# bmax = 0.09611402451992035
#
# Overimposed ripple:
# Sign changes of db/dt:
# No. of 1: 198 (sign changes)
# No. of 0: 4810
#
# Carrier signal:
# T_carrier = 0.000309375
# f_carrier = 3232.323232323232
# hmax = 36.63605880737305
# bmax = 0.17952026426792145
#
# Overimposed ripple:
# Sign changes of db/dt:
# No. of 1: 198 (sign changes)
# No. of 0: 4810
#
# Carrier signal:
# T_carrier = 0.000309375
# f_carrier = 3232.323232323232
# hmax = 27.15188217163086
# bmax = 0.12408760190010071
#
# Overimposed ripple:
# Sign changes of db/dt:
# No. of 1: 198 (sign changes)
# No. of 0: 4810
#
# Carrier signal:
# T_carrier = 0.000309375
# f_carrier = 3232.323232323232
# hmax = 17.91899871826172
# bmax = 0.07652638852596283
#
# Overimposed ripple:
# FrequencySet(
#   material_name='3C90',
#   frequency=500000.0,
#   H=f32[1300,3216],
#   B=f32[1300,3216],
#   T=f32[1300]
# )
#
# Sign changes of db/dt:
# No. of 1: 198 (sign changes)
# No. of 0: 3018
#
# Carrier signal:
# T_carrier = 0.000198
# f_carrier = 5050.505050505051
# hmax = 14.159658432006836
# bmax = 0.05884506180882454
#
# Overimposed ripple:
# Sign changes of db/dt:
# No. of 1: 198 (sign changes)
# No. of 0: 3018
#
# Carrier signal:
# T_carrier = 0.000198
# f_carrier = 5050.505050505051
# hmax = 42.52323532104492
# bmax = 0.21241812407970428
#
# Overimposed ripple:
# Sign changes of db/dt:
# No. of 1: 198 (sign changes)
# No. of 0: 3018
#
# Carrier signal:
# T_carrier = 0.000198
# f_carrier = 5050.505050505051
# hmax = 29.61052894592285
# bmax = 0.1395205557346344
#
# Overimposed ripple:
# Sign changes of db/dt:
# No. of 1: 198 (sign changes)
# No. of 0: 3018
#
# Carrier signal:
# T_carrier = 0.000198
# f_carrier = 5050.505050505051
# hmax = 18.30377960205078
# bmax = 0.07926169782876968
#
# Overimposed ripple:
# Sign changes of db/dt:
# No. of 1: 198 (sign changes)
# No. of 0: 3018
#
# Carrier signal:
# T_carrier = 0.000198
# f_carrier = 5050.505050505051
# hmax = 35.4797477722168
# bmax = 0.17572343349456787
#
# Overimposed ripple:
# Sign changes of db/dt:
# No. of 1: 198 (sign changes)
# No. of 0: 3018
#
# Carrier signal:
# T_carrier = 0.000198
# f_carrier = 5050.505050505051
# hmax = 31.261600494384766
# bmax = 0.14698177576065063
#
# Overimposed ripple:
# Sign changes of db/dt:
# No. of 1: 198 (sign changes)
# No. of 0: 3018
#
# Carrier signal:
# T_carrier = 0.000198
# f_carrier = 5050.505050505051
# hmax = 24.909481048583984
# bmax = 0.11121916025876999
#
# Overimposed ripple:
# Sign changes of db/dt:
# No. of 1: 198 (sign changes)
# No. of 0: 3018
#
# Carrier signal:
# T_carrier = 0.000198
# f_carrier = 5050.505050505051
# hmax = 38.9417839050293
# bmax = 0.1923474818468094
#
# Overimposed ripple:
# Sign changes of db/dt:
# No. of 1: 198 (sign changes)
# No. of 0: 3018
#
# Carrier signal:
# T_carrier = 0.000198
# f_carrier = 5050.505050505051
# hmax = 32.31755828857422
# bmax = 0.15410205721855164
#
# Overimposed ripple:
# Sign changes of db/dt:
# No. of 1: 198 (sign changes)
# No. of 0: 3018
#
# Carrier signal:
# T_carrier = 0.000198
# f_carrier = 5050.505050505051
# hmax = 24.904890060424805
# bmax = 0.11360205709934235
#
# Overimposed ripple:
# Sign changes of db/dt:
# No. of 1: 198 (sign changes)
# No. of 0: 3018
#
# Carrier signal:
# T_carrier = 0.000198
# f_carrier = 5050.505050505051
# hmax = 36.18172836303711
# bmax = 0.17798840999603271
#
# Overimposed ripple:
# Sign changes of db/dt:
# No. of 1: 198 (sign changes)
# No. of 0: 3018
#
# Carrier signal:
# T_carrier = 0.000198
# f_carrier = 5050.505050505051
# hmax = 30.01972007751465
# bmax = 0.14559787511825562
#
# Overimposed ripple:
# Sign changes of db/dt:
# No. of 1: 198 (sign changes)
# No. of 0: 3018
#
# Carrier signal:
# T_carrier = 0.000198
# f_carrier = 5050.505050505051
# hmax = 19.821739196777344
# bmax = 0.08746550977230072
#
# Overimposed ripple:
# FrequencySet(
#   material_name='3C90',
#   frequency=800000.0,
#   H=f32[1100,2016],
#   B=f32[1100,2016],
#   T=f32[1100]
# )
#
# Sign changes of db/dt:
# No. of 1: 198 (sign changes)
# No. of 0: 1818
#
# Carrier signal:
# T_carrier = 0.00012375
# f_carrier = 8080.808080808081
# hmax = 15.91559886932373
# bmax = 0.06807631254196167
#
# Overimposed ripple:
# Sign changes of db/dt:
# No. of 1: 198 (sign changes)
# No. of 0: 1818
#
# Carrier signal:
# T_carrier = 0.00012375
# f_carrier = 8080.808080808081
# hmax = 19.488542556762695
# bmax = 0.08569604903459549
#
# Overimposed ripple:
# Sign changes of db/dt:
# No. of 1: 198 (sign changes)
# No. of 0: 1818
#
# Carrier signal:
# T_carrier = 0.00012375
# f_carrier = 8080.808080808081
# hmax = 36.14341354370117
# bmax = 0.17688217759132385
#
# Overimposed ripple:
# Sign changes of db/dt:
# No. of 1: 198 (sign changes)
# No. of 0: 1818
#
# Carrier signal:
# T_carrier = 0.00012375
# f_carrier = 8080.808080808081
# hmax = 23.243345260620117
# bmax = 0.10163602232933044
#
# Overimposed ripple:
# Sign changes of db/dt:
# No. of 1: 198 (sign changes)
# No. of 0: 1818
#
# Carrier signal:
# T_carrier = 0.00012375
# f_carrier = 8080.808080808081
# hmax = 30.307344436645508
# bmax = 0.14557453989982605
#
# Overimposed ripple:
# Sign changes of db/dt:
# No. of 1: 198 (sign changes)
# No. of 0: 1818
#
# Carrier signal:
# T_carrier = 0.00012375
# f_carrier = 8080.808080808081
# hmax = 29.169391632080078
# bmax = 0.1353992521762848
#
# Overimposed ripple:
# Sign changes of db/dt:
# No. of 1: 198 (sign changes)
# No. of 0: 1818
#
# Carrier signal:
# T_carrier = 0.00012375
# f_carrier = 8080.808080808081
# hmax = 31.991607666015625
# bmax = 0.15339727699756622
#
# Overimposed ripple:
# Sign changes of db/dt:
# No. of 1: 198 (sign changes)
# No. of 0: 1818
#
# Carrier signal:
# T_carrier = 0.00012375
# f_carrier = 8080.808080808081
# hmax = 34.17251205444336
# bmax = 0.16303187608718872
#
# Overimposed ripple:
# Sign changes of db/dt:
# No. of 1: 198 (sign changes)
# No. of 0: 1818
#
# Carrier signal:
# T_carrier = 0.00012375
# f_carrier = 8080.808080808081
# hmax = 37.91702651977539
# bmax = 0.1951550394296646
#
# Overimposed ripple:
# Sign changes of db/dt:
# No. of 1: 198 (sign changes)
# No. of 0: 1818
#
# Carrier signal:
# T_carrier = 0.00012375
# f_carrier = 8080.808080808081
# hmax = 36.710689544677734
# bmax = 0.17699433863162994
#
# Overimposed ripple:
# Sign changes of db/dt:
# No. of 1: 198 (sign changes)
# No. of 0: 1818
#
# Carrier signal:
# T_carrier = 0.00012375
# f_carrier = 8080.808080808081
# hmax = 35.538612365722656
# bmax = 0.17498065531253815
#
# Overimposed ripple:
