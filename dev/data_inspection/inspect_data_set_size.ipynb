# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os
os.environ['CUDA_VISIBLE_DEVICES'] = '1'
os.environ["XLA_PYTHON_CLIENT_PREALLOCATE"]="false"

import jax
jax.config.update("jax_platform_name", "cpu")
jax.config.update("jax_enable_x64", True)

# %%
from rhmag.data_management import FINAL_MATERIALS, MaterialSet, DataSet, AVAILABLE_MATERIALS
from rhmag.utils.final_data_evaluation import TestSet

# %%
FINAL_MATERIALS

# %%
AVAILABLE_MATERIALS

# %%
eval_data_set = DataSet.from_material_names(FINAL_MATERIALS)

# %%
eval_data_set

# %%
number = 0

for material_set in eval_data_set:
    for frequency_set in material_set:
        number += frequency_set.H.size

print(number / 1e6)

# %%
test_data = {material_name: TestSet.from_material_name(material_name) for material_name in FINAL_MATERIALS}

# %%
number = 0
for material, material_test_set in test_data.items():
    number += material_test_set.H.size
print(number / 1e6)

# %%
PRETEST_MATERIALS = [material_name for material_name in AVAILABLE_MATERIALS if material_name not in FINAL_MATERIALS]
PRETEST_MATERIALS

# %%
data_set = DataSet.from_material_names(PRETEST_MATERIALS)

# %%
number = 0
for material_set in data_set:
    for frequency_set in material_set:
        number += frequency_set.H.size
print(number / 1e6)
