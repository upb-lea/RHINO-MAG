# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os
os.environ['CUDA_VISIBLE_DEVICES'] = '0'
os.environ["XLA_PYTHON_CLIENT_PREALLOCATE"]="false"

import pathlib
import glob
from copy import deepcopy

import tqdm
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

import jax
jax.config.update("jax_platform_name", "cpu")
# jax.config.update("jax_enable_x64", True)
import jax.numpy as jnp
import equinox as eqx

# %%
from mc2.utils.data_inspection import (
    get_available_material_names,
    get_file_overview,
    load_and_process_single_from_full_file_overview
)
from mc2.data_management import load_data_into_pandas_df, FrequencySet, MaterialSet, DataSet, DATA_ROOT, FINAL_MATERIALS, TestSet

# %% [markdown]
# - test for A, (B ?) is conceptually the same as pretest eval
# - test for C always starts with 0
# -

# %%
material_name = "A"
test_data = TestSet.from_material_name(material_name)

# %%
for scenario in test_data.scenarios:
    print(scenario.N_known)
    print(scenario.N_unknown)
    print(scenario.H_past.shape)
    print(scenario.H_past)

# %%
for seq_H, seq_B in zip(test_data.H[:10], test_data.B[:10]):
    plt.plot(seq_B / jnp.max(jnp.abs(seq_B)))
    plt.plot(seq_H / jnp.max(jnp.abs(seq_H[~jnp.isnan(seq_H)])))
    plt.show()

# %%
for seq_H, seq_B in zip(test_data.H[-10:], test_data.B[-10:]):
    plt.plot(seq_B / jnp.max(jnp.abs(seq_B)))
    plt.plot(seq_H / jnp.max(jnp.abs(seq_H[~jnp.isnan(seq_H)])))
    plt.show()
