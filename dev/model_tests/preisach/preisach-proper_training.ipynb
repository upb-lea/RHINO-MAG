# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os
os.environ['CUDA_VISIBLE_DEVICES'] = '0'
os.environ["XLA_PYTHON_CLIENT_PREALLOCATE"]="false"

import pathlib
import glob
import tqdm
from copy import deepcopy

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %% [markdown]
# ## Differentiable preisach model
#
# **Warning**: This is the standard version with B = f(H) and not actually what we need in the end!

# %%
import jax
import jax.numpy as jnp
import jax.nn as jnn
import jax
# jax.config.update("jax_platform_name", "cpu")
jax.config.update("jax_enable_x64", False)

import equinox as eqx
import optax

# %%
from rhmag.utils.data_plotting import plot_single_sequence, plot_hysteresis
from rhmag.data_management import FrequencySet, MaterialSet, DataSet
from rhmag.training.data_sampling import draw_data_uniformly

# %%
all_relevant_data = MaterialSet.from_material_name("3C90").at_frequency(320_000).filter_temperatures([25])
all_relevant_data = all_relevant_data.normalize() 
training_data, validation_data, testing_data = all_relevant_data.split_into_train_val_test(0.7, 0.15, 0.15)

# %%
def test_on_evalset(evaluation_data, model, alpha_beta_grid):
    batched_H = evaluation_data.H[:, :]
    batched_B = evaluation_data.B[:, :]
    
    pred_B = jax.vmap(model, in_axes=(0, None))(batched_H, alpha_beta_grid)

    for i in range(min(batched_H.shape[0], 3)):
        fig, axs = plot_single_sequence(batched_B[i], batched_H[i], jnp.unique(testing_data.T))
        axs[0].plot(pred_B[i], label="pred")
        fig.legend()
        plt.show()

# %%
from rhmag.models.preisach_utils import build_alpha_beta_grid
from rhmag.models.preisach import ArrayPreisach

# %%
@eqx.filter_jit
@eqx.filter_value_and_grad
def compute_loss_and_grad(model, H_trajectory, B_trajectory, alpha_beta_grid):
    B_est = jax.vmap(model, in_axes=(0, None))(H_trajectory, alpha_beta_grid)
    return jnp.mean((B_est - B_trajectory[..., None])**2)

# %%
model, alpha_beta_grid = ArrayPreisach.from_parameters(
    points_per_dim=50,
)

sequence_length = 100
training_batch_size = 64

key = jax.random.key(1)
key, _, loader_key = jax.random.split(key, 3)

optim = optax.adam(learning_rate=1e-3)
opt_state = optim.init(eqx.filter(model, eqx.is_inexact_array))

# %%
for n in tqdm.tqdm(range(100_000)):

    # sample data batches
    batched_H, batched_B, batched_T, _, loader_key = draw_data_uniformly(training_data, sequence_length, training_batch_size, loader_key)
    loss, grads = compute_loss_and_grad(model, batched_H, batched_B, alpha_beta_grid)
    updates, opt_state = optim.update(grads, opt_state)
    model = eqx.apply_updates(model, updates)


    if n % 10_000 == 0 and n > 0:
        test_on_evalset(testing_data, model, alpha_beta_grid)

# %%
batched_B = testing_data.B[:, :]
batched_H = testing_data.H[:, :]

pred_B = jax.vmap(model, in_axes=(0, None))(batched_H, alpha_beta_grid)

# %%
for i in range(min(batched_H.shape[0], 20)):
    fig, axs = plot_single_sequence(batched_B[i], batched_H[i], jnp.unique(testing_data.T))
    axs[0].plot(pred_B[i], label="pred")
    fig.legend()

# %%
for i in range(min(batched_H.shape[0], 20)):
    fig, axs = plot_hysteresis(batched_B[i], batched_H[i], jnp.unique(testing_data.T)) 
    fig, axs = plot_hysteresis(pred_B[i], batched_H[i], jnp.unique(testing_data.T), fig=fig, axs=axs)
    fig.legend()

# %% [markdown]
# ## quickly train a GRU on the same setup:

# %%
from rhmag.models.RNN import GRU

# %%
key = jax.random.key(1)
key, model_key, loader_key = jax.random.split(key, 3)


rnn_model = GRU(in_size=1, hidden_size=8, key=model_key)

optim = optax.adam(learning_rate=1e-3)
opt_state = optim.init(eqx.filter(rnn_model, eqx.is_inexact_array))

@eqx.filter_jit
@eqx.filter_value_and_grad
def compute_loss_and_grad_RNN(model, H_trajectory, B_trajectory, alpha_beta_grid):
    init_hidden = jnp.zeros((training_batch_size, rnn_model.hidden_size))

    H_trajectory = H_trajectory[..., None]
    
    B_est = eqx.filter_vmap(model)(H_trajectory, init_hidden)
    return jnp.mean((B_est - B_trajectory[..., None])**2)

# %%
for n in tqdm.tqdm(range(100_000)):

    # sample data batches
    batched_H, batched_B, batched_T, _, loader_key = draw_data_uniformly(training_data, sequence_length, training_batch_size, loader_key)
    loss, grads = compute_loss_and_grad_RNN(rnn_model, batched_H, batched_B, alpha_beta_grid)
    updates, opt_state = optim.update(grads, opt_state)
    rnn_model = eqx.apply_updates(rnn_model, updates)

# %%
batched_B = testing_data.B[:, :]
batched_H = testing_data.H[:, :]

init_hidden = jnp.zeros((batched_H.shape[0], rnn_model.hidden_size))
pred_B = eqx.filter_vmap(rnn_model)(batched_H[..., None], init_hidden)

# %%
for i in range(min(batched_H.shape[0], 20)):
    fig, axs = plot_single_sequence(batched_B[i], batched_H[i], jnp.unique(testing_data.T))
    axs[0].plot(pred_B[i], label="pred")
    fig.legend()

# %%
for i in range(min(batched_H.shape[0], 20)):
    fig, axs = plot_hysteresis(batched_B[i], batched_H[i], jnp.unique(testing_data.T)) 
    fig, axs = plot_hysteresis(pred_B[i], batched_H[i], jnp.unique(testing_data.T), fig=fig, axs=axs)
    fig.legend()

# %%
model_small, alpha_beta_grid = ArrayPreisach.from_parameters(
    points_per_dim=25,
)

sequence_length = 100
training_batch_size = 64

key = jax.random.key(1)
key, _, loader_key = jax.random.split(key, 3)

optim = optax.adam(learning_rate=1e-3)
opt_state = optim.init(eqx.filter(model_small, eqx.is_inexact_array))

# %%
for n in tqdm.tqdm(range(100_000)):

    # sample data batches
    batched_H, batched_B, batched_T, _, loader_key = draw_data_uniformly(training_data, sequence_length, training_batch_size, loader_key)
    loss, grads = compute_loss_and_grad(model_small, batched_H, batched_B, alpha_beta_grid)
    updates, opt_state = optim.update(grads, opt_state)
    model_small = eqx.apply_updates(model_small, updates)


    if n % 10_000 == 0 and n > 0:
        test_on_evalset(testing_data, model_small, alpha_beta_grid)

# %% [markdown]
# ## proper qualitative results:

# %%
batched_H.shape

# %%
import matplotlib as mpl
from matplotlib import rc
rc('font',**{'family':'serif','serif':['Helvetica']})
mpl.rcParams['text.usetex'] = True
mpl.rcParams.update({'font.size': 10})
mpl.rcParams['text.latex.preamble']=r"\usepackage{bm}\usepackage{amsmath}\usepackage{upgreek}"

# %%
H = testing_data.H[:, :]
B = testing_data.B[:, :]

init_hidden = jnp.zeros((H.shape[0], rnn_model.hidden_size))
pred_B_RNN = eqx.filter_vmap(rnn_model)(H[..., None], init_hidden)

_, alpha_beta_grid = ArrayPreisach.from_parameters(
    points_per_dim=50,
)
pred_B_preisach = jax.vmap(model, in_axes=(0, None))(H, alpha_beta_grid)

_, alpha_beta_grid = ArrayPreisach.from_parameters(
    points_per_dim=25,
)
pred_B_preisach_small = jax.vmap(model_small, in_axes=(0, None))(H, alpha_beta_grid)

# %%
# seq_idx = 20

# fig, axs = plt.subplots(1, 2, figsize=(7.167/2, 7.167/3), sharey="row")
# ax = axs[0]

# length = H.shape[-1]
# k = jnp.linspace(0, length-1, length)


# ax.plot(k, B[seq_idx], color="tab:blue", label="$B$", linewidth=1)
# ax.plot(k, pred_B_RNN[seq_idx], color="tab:orange", linestyle="--", label=r"$\hat{B}_RNN$", linewidth=1)
# ax.set_ylabel("$B$")
# ax.set_xlabel("$k$")
# ax.legend()
# ax.grid(True, alpha=0.3)


# ax = axs[1]

# ax.plot(k, B[seq_idx], color="tab:blue", label="$B$", linewidth=1)
# ax.plot(k, pred_B_preisach[seq_idx], color="tab:orange", linestyle="--", label=r"$\hat{B}_\mathrm{Preisach}$", linewidth=1)
# ax.set_xlabel("$k$")
# ax.legend()
# ax.grid(True, alpha=0.3)

# plt.tight_layout()

# # ax.plot(B[seq_idx], H[seq_idx], color="tab:blue", label="gt", linewidth=1)
# # ax.plot(B_past[seq_idx], H_past[seq_idx], color="tab:orange", linestyle="-", label="warmup", linewidth=1)
# # ax.plot(B_future[seq_idx], H_pred[seq_idx], color="tab:orange", linestyle="--", label=r"pred", linewidth=1)
# # ax.set_ylabel("$H$")
# # ax.set_xlabel("$B$")
# # ax.legend()
# # ax.grid(True, alpha=0.3)

# %%
seq_indices = [11, 20, 8]
seq_length = 500

fig, axs = plt.subplots(len(seq_indices), 1, figsize=(7.167/2, 7.167 * 2/3), sharex="col")
ax = axs[0]

length = H.shape[-1]
k = jnp.linspace(0, length-1, length)[:seq_length]

for seq_idx, ax in zip(seq_indices, axs):
    ax.plot(k, B[seq_idx, :seq_length], color="tab:blue", label="$\\tilde{B}$")
    ax.plot(k, pred_B_RNN[seq_idx, :seq_length], color="tab:orange", linestyle="--", label=r"$\hat{\tilde{B}}_\mathrm{GRU}$", alpha=.8)
    ax.plot(k, pred_B_preisach_small[seq_idx, :seq_length], color="tab:purple", linestyle="dashdot", label=r"$\hat{\tilde{B}}_\mathrm{Preisach}$", alpha=.8)
    #ax.plot(k, pred_B_preisach[seq_idx, :seq_length], color="tab:green", linestyle="dashed", label=r"$\hat{B}_\mathrm{Preisach}$")
    ax.set_ylabel("$\\tilde{B}$")
    ax.tick_params(which="major", axis="y", direction="in")
    ax.tick_params(which="both", axis="x", direction="in")
    ax.grid(True, alpha=0.3)


axs[0].legend(
    prop={"size": 8},
    framealpha=0.5,
    fancybox=True,
    shadow=False,
    ncols=3,
)
axs[-1].set_xlabel("$k$")
plt.tight_layout(h_pad=0.7)

plt.savefig("qual_comparison_preisach.pdf", bbox_inches="tight")

# %%
pred_B_RNN.shape

# %%
B.shape

# %%
pred_B_preisach_small.shape

# %%
from rhmag.metrics import default_metrics, evaluate_model_estimation

# %%
metrics_RNN = evaluate_model_estimation(
    H[..., None],
    B[..., None],
    pred_B_RNN,
    {"bh": {}, "h": default_metrics()["h"]},
)
metrics_RNN

# %%
metrics_Preisach = evaluate_model_estimation(
    H[..., None],
    B[..., None],
    pred_B_preisach_small,
    {"bh": {}, "h": default_metrics()["h"]},
)
metrics_Preisach

# %%
from rhmag.model_interfaces.model_interface import count_model_parameters

# %%
count_model_parameters(model_small)

# %%
count_model_parameters(rnn_model)
