# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os
os.environ['CUDA_VISIBLE_DEVICES'] = '0'
os.environ["XLA_PYTHON_CLIENT_PREALLOCATE"]="false"

import pathlib
import glob
from copy import deepcopy

import seaborn as sns
import tqdm
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

import jax
jax.config.update("jax_platform_name", "cpu")
jax.config.update("jax_enable_x64", True)
import jax.numpy as jnp
import equinox as eqx

# %%
from rhmag.utils.final_data_evaluation import (
    FINAL_MATERIALS, TestSet, ResultSet, predict_test_scenarios, validate_result_set, visualize_result_set
)
from rhmag.utils.model_evaluation import reconstruct_model_from_file, get_exp_ids

# %%
import matplotlib as mpl
from matplotlib import rc
rc('font',**{'family':'serif','serif':['Helvetica']})
mpl.rcParams['text.usetex'] = True
mpl.rcParams.update({'font.size': 10})
mpl.rcParams['text.latex.preamble']=r"\usepackage{bm}\usepackage{amsmath}\usepackage{upgreek}"

# %% [markdown]
# ---

# %% [markdown]
# ## Other teams:

# %%
from rhmag.utils.provided_final_results import EXTERNAL_TEAMS_AVG, EXTERNAL_TEAMS_PER_MATERIAL

# %%
df_external = pd.DataFrame(EXTERNAL_TEAMS_AVG)
df_external

# %% [markdown]
# ## Gather data:

# %%
FINAL_MATERIALS

# %%
test_data = {material_name: TestSet.from_material_name(material_name) for material_name in FINAL_MATERIALS}

# %%
exp_ids_all_seeds={}
exp_name="pareto-front-f32"
for material_name in FINAL_MATERIALS:
    print("MATERIAL:", material_name)
    mat_ids=sorted(get_exp_ids(material_name=material_name, model_type=None, exp_name=exp_name))
    mat_ids_ja = sorted(get_exp_ids(material_name=material_name, model_type="JA", exp_name="pareto-front-f64"))
    mat_ids = mat_ids_ja + mat_ids #+ sorted(get_exp_ids(material_name=material_name, model_type="GRU", exp_name="pareto-front-posttrained-f32"))
    
    mat_ids_unique = list(set(mat_ids))

    [print("    " + f"'{element}'") for element in mat_ids_unique]
    print()

    exp_ids_all_seeds[material_name]=mat_ids_unique

# %%
for material_name, mat_ids_unique in exp_ids_all_seeds.items():
    print(f"Material '{material_name}': {len(mat_ids_unique)} models found.")

# %% [markdown]
# ## Update df:

# %%
from rhmag.utils.final_data_evaluation import update_pareto_df

# %%
df_results = update_pareto_df("pareto_results_OJS.parquet", exp_ids_all_seeds, test_data)
df_results.to_parquet("pareto_results_OJS.parquet")

# %%
# df_results = df_results[~df_results['model_type'].str.contains('GRUpost', na=False)].reset_index()
# df_results.to_parquet("pareto_results_OJS.parquet")

# %%
df_results

# %%
#df_results = df_results.drop('index', axis=1)

# %% [markdown]
# ## Visualize pareto from across models:

# %%
material_name_map = {
    "A": "3C92",
    "B": "3C95",
    "C": "FEC007",
    "D": "FEC014",
    "E": "T37",
}

# %%
df_results

# %%
# check for pretrained data
# further redundant entries?
# count results per category

subset = ["exp_name", "material", "model_type", "seed", "n_params"]
duplicates = df_results[df_results.duplicated(subset=subset, keep=False)].sort_values(subset)
with pd.option_context('display.max_rows', None, 'display.max_columns', None):
    display(duplicates)

print(len(duplicates))

# %%
# subset = ["material", "model_type", "seed", "n_params"]
# duplicates = df_results[df_results.duplicated(subset=subset)].sort_values(subset)
# len(duplicates)

# %% [markdown]
# ## Filter out MSE results:
#
# Only filters if the parameter files are locally available (Should not be a problem, because I am the only person doing this?)

# %%
import json
from rhmag.data_management import MODEL_DUMP_ROOT

def load_parameterization(filename):
    filename = pathlib.Path(filename)

    # append the '.eqx' suffix if it is missing
    if filename.suffix == "":
        filename = filename.with_name(f"{filename.name}.eqx")

    # check for the filename in the 'MODEL_DUMP_ROOT' if it is not already an existing file
    if filename.is_file():
        filename = filename
    else:
        search_path = MODEL_DUMP_ROOT / filename
        if search_path.is_file():
            print(f"Found model file at '{search_path}'. Loading model..")
            filename = search_path
        else:
            raise ValueError(f"No model could be found for the specified filepath: '{filename}'")

    with open(filename, "rb") as f:
        params = json.loads(f.readline().decode())

    return params

# %%
loss_types = {}
for exp_id in duplicates[duplicates["material"] == "A"].sort_values(subset)["exp_id"]:
    try:
        loss_types[exp_id] = load_parameterization(exp_id)["loss_type"]
    except:
        pass

# %%
loss_types

# %%
MSE_exps = []
for exp_id, loss_type in loss_types.items():
    if loss_type == "MSE":
        MSE_exps.append(exp_id)
    else:
        pass
MSE_exps

# %%
df_results = df_results[~df_results["exp_id"].isin(MSE_exps)]
df_results

# %%
subset = ["material", "model_type", "seed", "n_params"]
duplicates = df_results[df_results.duplicated(subset=subset)].sort_values(subset)
len(duplicates)

# %%
model_sizes = df_results.groupby(["material", "model_type"]).size()
with pd.option_context('display.max_rows', None, 'display.max_columns', None):
    display(pd.DataFrame(model_sizes))

# %%
n_models = df_results.groupby(["material"]).size()
n_models

# %%
no_duplicates_result = df_results[~df_results.duplicated(subset=subset, keep="first")]

# %%
no_duplicates_result.groupby(["material"]).size()

# %%
model_sizes = no_duplicates_result.groupby(["material", "model_type"]).size()
with pd.option_context('display.max_rows', None, 'display.max_columns', None):
    display(pd.DataFrame(model_sizes))

# %%
with pd.option_context('display.max_rows', None, 'display.max_columns', None):
    display(no_duplicates_result.sort_values(subset))

# %%
len(duplicates)

# %% [markdown]
# ---
# ---
# ---

# %%
from rhmag.utils.pareto_plot_functions import visualize_pareto_cross_model, visualize_pareto_single_plot

# %%
90 / 5

# %%
external_df = pd.read_parquet("extract_results/external_pareto_results.parquet")
external_df

# %%
dfs_per_material = [x for _, x in no_duplicates_result.groupby("material")]
for material_name, df in zip(FINAL_MATERIALS, dfs_per_material):
    assert (df.material == material_name).all()
dfs_per_material = {material_name: df for material_name, df in zip(FINAL_MATERIALS, dfs_per_material)}

external_df = pd.read_parquet("extract_results/external_pareto_results.parquet")
external_df_per_material = [x for _, x in external_df.groupby("material")]
external_df_per_material = {material_name: df for material_name, df in zip(FINAL_MATERIALS, external_df_per_material)}

# %%
visualize_pareto_single_plot(
    dfs_per_material,
    external_df_per_material,
    metrics=["sre","nere"],
    colors={
        "GRU": "tab:blue",
        "LSTM": "tab:orange",
        "JA": "tab:cyan",
        "GRUwLinearModel": "tab:green",
        "MagnetizationGRU": "tab:purple",
        "JADirectParamGRU": "tab:brown",
        #"GRUpost": "black",
        "VectorfieldGRU": "tab:olive",
    },
    labels={
        "GRU": "GRU-P",
        "LSTM": "LSTM",
        "JA": "JA",
        "GRUwLinearModel": "GRU-L",
        "MagnetizationGRU": "GRU-M",
        "JADirectParamGRU": "GRU-JADP",
        #"GRUpost": "P-GRU-P",'
        "VectorfieldGRU": "GRU-V",
    },
    color_others="black",
    sharex=False,
    sharey="row",
    material_name_map=material_name_map,
    xlims=[
        ((0.12, 1.2),(0.007, 0.3)),
        ((0.05, 1.2),(0.007, 0.3)),
        ((0.11, 1.5),(0.03, 0.5)),
        ((0.05, 1.2),(0.015, 0.5)),
        ((0.08, 1.5),(0.004, 0.3)),
    ],
    show_median=True,
    figsize=(7.167, 8.5),
    label_placement_external={
        "A": {
            "sre_95th": {
                "Fuzhou": ("center","top"),
                "Eindhoven": ("center","bottom"),
                "Southeast1": ("center", "top"),
                "IIT": ("center", "top"),
                "SiegenPaderborn": ("left", "center"),
                "Gatech": ("center", "top"),
                "Tianjin": ("right", "center"),
                "Zhejiang": ("right", "center"),
                "ASU": ("center", "bottom"),
                "XJTU2": ("center", "top"),
                "Princeton": ("center", "top"),
                "SAL": ("right", "center"),
                "UESTC": ("center", "top"),
            },
            "nere_95th": {
                "Fuzhou": ("center","top"),
                "IIT": ("center", "bottom"),
                "Eindhoven": ("center", "bottom"),
                "Tianjin": ("center", "bottom"),
                "SAL": ("right", "center"),
                "Princeton": ("right", "center"),
                "Cambridge": ("right", "center"),
                "ASU": ("center", "bottom"),
                "XJTU2": ("center", "top"),
                "NTU2": ("center", "top"),
            }
        },
        "B": {
            "sre_95th": {
                "Fuzhou": ("right","center"),
                "Eindhoven": ("center","bottom"),
                "Southeast1": ("right", "center"),
                "IIT": ("center", "bottom"),
                "SiegenPaderborn": ("right", "center"),
                "Gatech": ("center", "top"),
                "Tianjin": ("center", "bottom"),
                "Zhejiang": ("center", "bottom"),
                "ASU": ("left", "center"),
                "XJTU2": ("center", "top"),
                "Princeton": ("center", "top"),
                "SAL": ("left", "center"),
                "Sydney": ("right", "center"),
            },
            "nere_95th": {
                "Fuzhou": ("right","center"),
                "Eindhoven": ("center","bottom"),
                "Southeast1": ("right", "center"),
                "IIT": ("center", "bottom"),
                "SiegenPaderborn": ("right", "center"),
                "Gatech": ("center", "top"),
                "Tianjin": ("center", "bottom"),
                "Zhejiang": ("center", "bottom"),
                "ASU": ("left", "center"),
                "XJTU2": ("center", "top"),
                "SAL": ("left", "center"),
                "Sydney": ("right", "center"),
                "Cambridge": ("right", "center")
            },
        },
        "C": {
            "sre_95th": {
                "Fuzhou": ("center","top"),
                "Eindhoven": ("center","bottom"),
                "Southeast1": ("center", "top"),
                "IIT": ("center", "bottom"),
                "SiegenPaderborn": ("right", "center"),
                "Gatech": ("center", "top"),
                "Tianjin": ("left", "center"),
                "Zhejiang": ("center", "bottom"),
                "ASU": ("left", "center"),
                "XJTU2": ("center", "top"),
                "Princeton": ("center", "top"),
                "SAL": ("center", "top"),
                "Sydney": ("right", "center"),
                "Hefei": ("center", "top"),
                "Cambridge": ("right", "center"),
            },
            "nere_95th": {
                "Fuzhou": ("right","center"),
                "Eindhoven": ("center","bottom"),
                "Southeast1": ("right", "center"),
                "IIT": ("center", "bottom"),
                "SiegenPaderborn": ("center", "top"),
                "Gatech": ("center", "top"),
                "Tianjin": ("left", "center"),
                "Zhejiang": ("right", "center"),
                "ASU": ("left", "center"),
                "XJTU2": ("center", "top"),
                "SAL": ("left", "center"),
                "Sydney": ("right", "center"),
                "Cambridge": ("right", "center"),
                "Hefei": ("right", "center"),
                "ASU": ("right", "center"),
                "UESTC": ("right", "center"),
                "NTU2": ("right", "center"),
                "Princeton": ("right", "center"),
            },
        },
        "D": {
            "sre_95th": {
                "Fuzhou": ("right", "center"),
                "Southeast1": ("right", "center"),
                "Sydney": ("right", "center"),
                "SiegenPaderborn": ("right", "center"),
                "Gatech": ("right", "center"),
                "Cambridge": ("right", "center"),
                "Eindhoven": ("center","bottom"),
                "IIT": ("center", "bottom"),
                "Zhejiang": ("right", "center"),
                "SAL": ("center","top"),
                "NTU2": ("center", "bottom"),
                "Tianjin": ("right", "center"),
            },
            "nere_95th": {
                "Fuzhou": ("right", "center"),
                "Southeast1": ("right", "center"),
                "Sydney": ("right", "center"),
                "SiegenPaderborn": ("center", "top"),
                "Gatech": ("right", "center"),
                "ASU": ("center", "bottom"),
                "Eindhoven": ("center","bottom"),
                "IIT": ("center", "bottom"),
                "Tianjin": ("center", "bottom"),
            },
        },
        "E": {
            "sre_95th": {
                "Eindhoven": ("center","bottom"),
                "IIT": ("center", "bottom"),
                "Sydney": ("right", "center"),
                "Gatech": ("right", "center"),
                "ASU": ("right", "center"),
            },
            "nere_95th": {
                "Fuzhou": ("right", "center"),
                "Southeast1": ("right", "center"),
                "Eindhoven": ("center","bottom"),
                "IIT": ("center", "bottom"),
                "Cambridge": ("right", "center"),
                "SAL": ("right", "center"),
                "ASU": ("right", "center"),
                "UESTC": ("right", "center"),
                "XJTU2": ("right", "center"),
            },
        },
    },
    show_external_names=True,
)
#plt.show()
plt.savefig(f"pareto_investigation_all_materials.svg", bbox_inches="tight")

# %%
raise

# %%
# for material_name, df_material in dfs_per_material.items():

#     if material_name=="A":
#         show_legend=True
#     else:
#         show_legend=False
    
#     fig, axs = visualize_pareto_cross_model(
#         df_material,
#         external_df_per_material[material_name],
#         metrics=["sre","nere"],
#         colors={
#             "GRU": "tab:blue",
#             "LSTM": "tab:orange",
#             "JA": "tab:cyan",
#             "GRUwLinearModel": "tab:green",
#             "MagnetizationGRU": "tab:purple",
#             "JADirectParamGRU": "tab:brown",
#             "GRUpost": "black",
#             "VectorfieldGRU": "tab:olive",
#         },
#         labels={
#             "GRU": "GRU-P",
#             "LSTM": "LSTM",
#             "JA": "JA",
#             "GRUwLinearModel": "GRU-L",
#             "MagnetizationGRU": "GRU-M",
#             "JADirectParamGRU": "GRU-JADP",
#             "GRUpost": "P-GRU-P",
#             "VectorfieldGRU": "GRU-V",
#         },
#         color_others="black",
#         sharex="col",
#         sharey="row",
#         xlim=None,
#         show_median=True,
#         figsize=(7.167, 7.167 / 2),
#         show_legend=show_legend,
#     )
#     fig.suptitle(f"Pareto investigation for material '{material_name}'")
#     plt.tight_layout()
#     #plt.savefig(f"pareto_investigation_material_each_trial_{material_name}.png", dpi=250, facecolor='white', transparent=False)
#     plt.savefig(f"pareto_investigation_material_each_trial_{material_name}.pdf", bbox_inches="tight")

# %%
# fig, axs = visualize_pareto_cross_model(
#     df_results,
#     df_external,
#     metrics=["sre","nere"],
#     colors={
#         "GRU": "tab:blue",
#         "LSTM": "tab:orange",
#         "JA": "tab:purple",
#         "GRUwLinearModel": "tab:green",
#         "MagnetizationGRU": "tab:brown",
#         "JAWithGRU": "tab:cyan",
#     },
#     color_others="black",
#     sharex="col",
#     sharey="row",
#     xlim=None,
#     show_median=True,
# )
