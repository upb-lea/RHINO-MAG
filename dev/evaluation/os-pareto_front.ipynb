# %% [markdown]
# # GRU Pareto Front:

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os
os.environ["JAX_PLATFORMS"]="cpu"
os.environ['CUDA_VISIBLE_DEVICES'] = ''
os.environ["XLA_PYTHON_CLIENT_PREALLOCATE"] = "false"

import pickle
import collections
import glob
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from pathlib import Path
import pathlib
from typing import Type
import json

import jax
import jax.numpy as jnp
jax.config.update("jax_platform_name", "cpu")
jax.config.update("jax_enable_x64", False)
import equinox as eqx

#from mc2.runners.model_setup_jax import get_normalizer
from mc2.data_management import MaterialSet, FINAL_MATERIALS, EXPERIMENT_LOGS_ROOT, MODEL_DUMP_ROOT, NORMALIZATION_ROOT
from mc2.models.jiles_atherton import JAStatic, JAWithGRU
from mc2.models.RNN import GRU
from mc2.model_interfaces.model_interface import ModelInterface, load_model, count_model_parameters

# %%
from mc2.utils.model_evaluation import reconstruct_model_from_exp_id, get_exp_ids, evaluate_cross_validation, load_parameterization
from mc2.utils.final_data_evaluation import FINAL_SCENARIOS_PER_MATERIAL
from IPython.display import display, HTML
from mc2.utils.pretest_evaluation import HOSTS_VALUES_DICT, evaluate_pretest_scenarios, create_multilevel_df, SCENARIO_LABELS

# %% [markdown]
# ---

# %%
FINAL_MATERIALS
# Out:
# ['A', 'B', 'C', 'D', 'E']

# %%
exp_ids_no_seed={}
exp_name="final-comp-reduced"
for material_name in FINAL_MATERIALS:
    print("MATERIAL:", material_name)
    mat_ids=[element.rpartition('_')[0] for element in sorted(get_exp_ids(material_name=material_name, model_type=None)) if exp_name in element]
    mat_ids_unique= list(set(mat_ids))
    [print("    " + f"'{element}'") for element in mat_ids_unique]
    #print(len(get_exp_ids(material_name=material_name, model_type=None)))
    print()
    exp_ids_no_seed[material_name]=mat_ids_unique

#sorted(get_exp_ids(material_name="E", model_type=None))
# Out:
# MATERIAL: A
#     'A_GRU6_final-comp-reduced_c4bf6467'
#     'A_GRU32_final-comp-reduced_b12e3229'
#     'A_GRU2_final-comp-reduced_4b93d1af'
#     'A_GRU16_final-comp-reduced_af2466d9'
#     'A_GRU4_final-comp-reduced_4b52e44c'
#     'A_GRU6_final-comp-reduced_dbc18ee7'
#     'A_GRU8_final-comp-reduced_1acf73f0'
#     'A_GRU16_final-comp-reduced_3b939dc8'
#     'A_GRU10_final-comp-reduced_75393ffa'
#     'A_GRU10_final-comp-reduced_7fd202d7'
#     'A_GRU2_final-comp-reduced_ef8a97e0'
#     'A_GRU32_final-comp-reduced_a6d6a717'
#     'A_GRU8_final-comp-reduced_430fd3f5'
#     'A_GRU4_final-comp-reduced_d4dae3d4'
#
# MATERIAL: B
#     'B_GRU6_final-comp-reduced_555bdfcd'
#     'B_GRU10_final-comp-reduced_96c79ca5'
#     'B_GRU2_final-comp-reduced_f89c16f8'
#     'B_GRU4_final-comp-reduced_93984182'
#     'B_GRU10_final-comp-reduced_b07266f5'
#     'B_GRU32_final-comp-reduced_de405193'
#     'B_GRU4_final-comp-reduced_868eb75a'
#     'B_GRU6_final-comp-reduced_00713de0'
#     'B_GRU8_final-comp-reduced_79099b6c'
#     'B_GRU16_final-comp-reduced_27369a81'
#     'B_GRU32_final-comp-reduced_6bd4bc13'
#     'B_GRU2_final-comp-reduced_c0440310'
#     'B_GRU16_final-comp-reduced_109d9989'
#     'B_GRU8_final-comp-reduced_1976601c'
#
# MATERIAL: C
#     'C_GRU32_final-comp-reduced_61216567'
#     'C_GRU10_final-comp-reduced_4109a7eb'
#     'C_GRU2_final-comp-reduced_b1015b51'
#     'C_GRU6_final-comp-reduced_7409273e'
#     'C_GRU16_final-comp-reduced_bd97474d'
#     'C_GRU16_final-comp-reduced_192cb37a'
#     'C_GRU6_final-comp-reduced_0518bb0a'
#     'C_GRU10_final-comp-reduced_5c9a08f9'
#     'C_GRU4_final-comp-reduced_da0a9659'
#     'C_GRU8_final-comp-reduced_edc2ad25'
#     'C_GRU8_final-comp-reduced_c6c1668c'
#     'C_GRU10_final-comp-reduced_78fa7f79'
#     'C_GRU32_final-comp-reduced_438412a5'
#     'C_GRU4_final-comp-reduced_10e73620'
#     'C_GRU2_final-comp-reduced_d6a11473'
#
# MATERIAL: D
#     'D_GRU8_final-comp-reduced_fe968aea'
#     'D_GRU6_final-comp-reduced_aaeb1e29'
#     'D_GRU2_final-comp-reduced_73b05bda'
#     'D_GRU6_final-comp-reduced_3ec57bbb'
#     'D_GRU10_final-comp-reduced_087b29b0'
#     'D_GRU32_final-comp-reduced_52d84ab9'
#     'D_GRU2_final-comp-reduced_0541be99'
#     'D_GRU8_final-comp-reduced_178cf7b0'
#     'D_GRU16_final-comp-reduced_75b873fe'
#     'D_GRU4_final-comp-reduced_84b5a8b2'
#     'D_GRU16_final-comp-reduced_08f5eb44'
#     'D_GRU10_final-comp-reduced_e70f639d'
#     'D_GRU4_final-comp-reduced_536ff523'
#     'D_GRU32_final-comp-reduced_882c3c7d'
#
# MATERIAL: E
#     'E_GRU8_final-comp-reduced_2a51a699'
#     'E_GRU6_final-comp-reduced_f9e1315f'
#     'E_GRU10_final-comp-reduced_77aa48f1'
#     'E_GRU16_final-comp-reduced_b9ebcce9'
#     'E_GRU8_final-comp-reduced_5fbc79a6'
#     'E_GRU32_final-comp-reduced_b94cc9dd'
#     'E_GRU4_final-comp-reduced_57f3ad88'
#     'E_GRU16_final-comp-reduced_76b873de'
#     'E_GRU2_final-comp-reduced_74476fd0'
#     'E_GRU32_final-comp-reduced_c4841e59'
#     'E_GRU6_final-comp-reduced_12582f45'
#     'E_GRU4_final-comp-reduced_35964129'
#     'E_GRU10_final-comp-reduced_160434b5'
#     'E_GRU2_final-comp-reduced_38e16675'

# %% [markdown]
# ## Compute metrics for trained models

# %%
from mc2.utils.final_data_evaluation import generate_metrics_from_exp_ids_without_seed

# %%
dfs={}
for material_name in FINAL_MATERIALS:
    if exp_ids_no_seed[material_name]:
        dfs[material_name], _ = generate_metrics_from_exp_ids_without_seed(
            exp_ids_without_seed=exp_ids_no_seed[material_name],
            material_name=material_name,
            loader_key=jax.random.PRNGKey(99),
        )
        # file_path_pickle = f'results__dump_material_reduced_{material_name}.pkl'
        # with open(file_path_pickle, 'wb') as f:
        #     pickle.dump(dfs[material_name], f)
    else:
        print(f"Skipping Material {material_name} due to missing exp_ids.")
df_all= pd.concat([dfs["A"],dfs["B"],dfs["C"],dfs["D"],dfs["E"]], ignore_index=True)
df_all.to_pickle('results_pareto_front.pkl')
# Out:
# Found model file at '/home/oliverjs@uni-paderborn.de/mc_2/magnet-challenge-2/data/models/A_GRU32_final-comp-reduced_b12e3229_seed3.eqx'. Loading model..
# Found model file at '/home/oliverjs@uni-paderborn.de/mc_2/magnet-challenge-2/data/models/A_GRU4_final-comp-reduced_4b52e44c_seed5.eqx'. Loading model..
# Found model file at '/home/oliverjs@uni-paderborn.de/mc_2/magnet-challenge-2/data/models/A_GRU32_final-comp-reduced_a6d6a717_seed5.eqx'. Loading model..
# Found model file at '/home/oliverjs@uni-paderborn.de/mc_2/magnet-challenge-2/data/models/A_GRU16_final-comp-reduced_3b939dc8_seed3.eqx'. Loading model..
# Found model file at '/home/oliverjs@uni-paderborn.de/mc_2/magnet-challenge-2/data/models/A_GRU2_final-comp-reduced_4b93d1af_seed1.eqx'. Loading model..
# Found model file at '/home/oliverjs@uni-paderborn.de/mc_2/magnet-challenge-2/data/models/A_GRU4_final-comp-reduced_4b52e44c_seed4.eqx'. Loading model..
# Found model file at '/home/oliverjs@uni-paderborn.de/mc_2/magnet-challenge-2/data/models/A_GRU10_final-comp-reduced_7fd202d7_seed4.eqx'. Loading model..
# Found model file at '/home/oliverjs@uni-paderborn.de/mc_2/magnet-challenge-2/data/models/A_GRU10_final-comp-reduced_75393ffa_seed2.eqx'. Loading model..
# Found model file at '/home/oliverjs@uni-paderborn.de/mc_2/magnet-challenge-2/data/models/A_GRU4_final-comp-reduced_d4dae3d4_seed3.eqx'. Loading model..
# Found model file at '/home/oliverjs@uni-paderborn.de/mc_2/magnet-challenge-2/data/models/A_GRU8_final-comp-reduced_430fd3f5_seed4.eqx'. Loading model..
# Found model file at '/home/oliverjs@uni-paderborn.de/mc_2/magnet-challenge-2/data/models/A_GRU2_final-comp-reduced_ef8a97e0_seed4.eqx'. Loading model..
# Found model file at '/home/oliverjs@uni-paderborn.de/mc_2/magnet-challenge-2/data/models/A_GRU32_final-comp-reduced_a6d6a717_seed4.eqx'. Loading model..
# Found model file at '/home/oliverjs@uni-paderborn.de/mc_2/magnet-challenge-2/data/models/A_GRU6_final-comp-reduced_c4bf6467_seed1.eqx'. Loading model..
# Found model file at '/home/oliverjs@uni-paderborn.de/mc_2/magnet-challenge-2/data/models/A_GRU32_final-comp-reduced_b12e3229_seed2.eqx'. Loading model..
# Found model file at '/home/oliverjs@uni-paderborn.de/mc_2/magnet-challenge-2/data/models/A_GRU8_final-comp-reduced_1acf73f0_seed2.eqx'. Loading model..
# Found model file at '/home/oliverjs@uni-paderborn.de/mc_2/magnet-challenge-2/data/models/A_GRU4_final-comp-reduced_d4dae3d4_seed1.eqx'. Loading model..
# Found model file at '/home/oliverjs@uni-paderborn.de/mc_2/magnet-challenge-2/data/models/A_GRU8_final-comp-reduced_430fd3f5_seed5.eqx'. Loading model..
# Found model file at '/home/oliverjs@uni-paderborn.de/mc_2/magnet-challenge-2/data/models/A_GRU2_final-comp-reduced_ef8a97e0_seed5.eqx'. Loading model..
# Found model file at '/home/oliverjs@uni-paderborn.de/mc_2/magnet-challenge-2/data/models/A_GRU6_final-comp-reduced_dbc18ee7_seed5.eqx'. Loading model..
# Found model file at '/home/oliverjs@uni-paderborn.de/mc_2/magnet-challenge-2/data/models/A_GRU2_final-comp-reduced_4b93d1af_seed2.eqx'. Loading model..
# Found model file at '/home/oliverjs@uni-paderborn.de/mc_2/magnet-challenge-2/data/models/A_GRU16_final-comp-reduced_af2466d9_seed4.eqx'. Loading model..
# Found model file at '/home/oliverjs@uni-paderborn.de/mc_2/magnet-challenge-2/data/models/A_GRU6_final-comp-reduced_c4bf6467_seed3.eqx'. Loading model..
# Found model file at '/home/oliverjs@uni-paderborn.de/mc_2/magnet-challenge-2/data/models/A_GRU16_final-comp-reduced_3b939dc8_seed1.eqx'. Loading model..
# Found model file at '/home/oliverjs@uni-paderborn.de/mc_2/magnet-challenge-2/data/models/A_GRU32_final-comp-reduced_b12e3229_seed1.eqx'. Loading model..
# Found model file at '/home/oliverjs@uni-paderborn.de/mc_2/magnet-challenge-2/data/models/A_GRU16_final-comp-reduced_3b939dc8_seed2.eqx'. Loading model..
# Found model file at '/home/oliverjs@uni-paderborn.de/mc_2/magnet-challenge-2/data/models/A_GRU10_final-comp-reduced_7fd202d7_seed5.eqx'. Loading model..
# Found model file at '/home/oliverjs@uni-paderborn.de/mc_2/magnet-challenge-2/data/models/A_GRU6_final-comp-reduced_c4bf6467_seed2.eqx'. Loading model..
# Found model file at '/home/oliverjs@uni-paderborn.de/mc_2/magnet-challenge-2/data/models/A_GRU6_final-comp-reduced_dbc18ee7_seed4.eqx'. Loading model..
# Found model file at '/home/oliverjs@uni-paderborn.de/mc_2/magnet-challenge-2/data/models/A_GRU8_final-comp-reduced_1acf73f0_seed3.eqx'. Loading model..
# Found model file at '/home/oliverjs@uni-paderborn.de/mc_2/magnet-challenge-2/data/models/A_GRU2_final-comp-reduced_4b93d1af_seed3.eqx'. Loading model..
# Found model file at '/home/oliverjs@uni-paderborn.de/mc_2/magnet-challenge-2/data/models/A_GRU8_final-comp-reduced_1acf73f0_seed1.eqx'. Loading model..
# Found model file at '/home/oliverjs@uni-paderborn.de/mc_2/magnet-challenge-2/data/models/A_GRU16_final-comp-reduced_af2466d9_seed5.eqx'. Loading model..
# Found model file at '/home/oliverjs@uni-paderborn.de/mc_2/magnet-challenge-2/data/models/A_GRU10_final-comp-reduced_75393ffa_seed3.eqx'. Loading model..
# Found model file at '/home/oliverjs@uni-paderborn.de/mc_2/magnet-challenge-2/data/models/A_GRU4_final-comp-reduced_d4dae3d4_seed2.eqx'. Loading model..
# Found model file at '/home/oliverjs@uni-paderborn.de/mc_2/magnet-challenge-2/data/models/A_GRU10_final-comp-reduced_75393ffa_seed1.eqx'. Loading model..
# Loading data for A: 100%|██████████| 21/21 [00:05<00:00,  3.86it/s]
# Normalized Energy relative error cannot be properly computed as the core losses are unknown. Setting 'true_core_loss=1'.
# Normalized Energy relative error cannot be properly computed as the core losses are unknown. Setting 'true_core_loss=1'.
# Normalized Energy relative error cannot be properly computed as the core losses are unknown. Setting 'true_core_loss=1'.
# 	MSE :   13.35 (A/m)²
# 	WCE :   53.24 A/m
# 	MSE :   12.46 (A/m)²
# 	WCE :   52.03 A/m
# 	MSE :   10.20 (A/m)²
# 	WCE :   58.14 A/m
# Normalized Energy relative error cannot be properly computed as the core losses are unknown. Setting 'true_core_loss=1'.
# Normalized Energy relative error cannot be properly computed as the core losses are unknown. Setting 'true_core_loss=1'.
# Normalized Energy relative error cannot be properly computed as the core losses are unknown. Setting 'true_core_loss=1'.
# 	MSE :   29.84 (A/m)²
# 	WCE :  131.17 A/m
# 	MSE :   25.21 (A/m)²
# 	WCE :  128.33 A/m
# 	MSE :   13.01 (A/m)²
# 	WCE :  111.66 A/m
# Normalized Energy relative error cannot be properly computed as the core losses are unknown. Setting 'true_core_loss=1'.
# Normalized Energy relative error cannot be properly computed as the core losses are unknown. Setting 'true_core_loss=1'.
# Normalized Energy relative error cannot be properly computed as the core losses are unknown. Setting 'true_core_loss=1'.
# 	MSE :   16.53 (A/m)²
# 	WCE :  112.98 A/m
# 	MSE :   16.28 (A/m)²
# 	WCE :  114.42 A/m
# 	MSE :    9.65 (A/m)²
# 	WCE :   91.12 A/m
# Normalized Energy relative error cannot be properly computed as the core losses are unknown. Setting 'true_core_loss=1'.
# Normalized Energy relative error cannot be properly computed as the core losses are unknown. Setting 'true_core_loss=1'.
# Normalized Energy relative error cannot be properly computed as the core losses are unknown. Setting 'true_core_loss=1'.
# 	MSE :   18.48 (A/m)²
# 	WCE :   94.07 A/m
# 	MSE :   18.16 (A/m)²
# 	WCE :   94.03 A/m
# 	MSE :   13.18 (A/m)²
# 	WCE :   86.33 A/m
# Normalized Energy relative error cannot be properly computed as the core losses are unknown. Setting 'true_core_loss=1'.
# Normalized Energy relative error cannot be properly computed as the core losses are unknown. Setting 'true_core_loss=1'.
# Normalized Energy relative error cannot be properly computed as the core losses are unknown. Setting 'true_core_loss=1'.
# 	MSE :   51.09 (A/m)²
# 	WCE :  142.23 A/m
# 	MSE :   47.80 (A/m)²
# 	WCE :  142.17 A/m
# 	MSE :   33.74 (A/m)²
# 	WCE :  128.21 A/m
# Normalized Energy relative error cannot be properly computed as the core losses are unknown. Setting 'true_core_loss=1'.
# Normalized Energy relative error cannot be properly computed as the core losses are unknown. Setting 'true_core_loss=1'.
# Normalized Energy relative error cannot be properly computed as the core losses are unknown. Setting 'true_core_loss=1'.
# 	MSE :   28.23 (A/m)²
# 	WCE :   84.57 A/m
# 	MSE :   26.52 (A/m)²
# 	WCE :   83.26 A/m
# 	MSE :   19.48 (A/m)²
# 	WCE :   60.16 A/m
# Normalized Energy relative error cannot be properly computed as the core losses are unknown. Setting 'true_core_loss=1'.
# Normalized Energy relative error cannot be properly computed as the core losses are unknown. Setting 'true_core_loss=1'.
# Normalized Energy relative error cannot be properly computed as the core losses are unknown. Setting 'true_core_loss=1'.
# 	MSE :   13.44 (A/m)²
# 	WCE :   55.31 A/m
# 	MSE :   12.17 (A/m)²
# 	WCE :   44.44 A/m
# 	MSE :    8.10 (A/m)²
# 	WCE :   44.44 A/m
# Normalized Energy relative error cannot be properly computed as the core losses are unknown. Setting 'true_core_loss=1'.
# Normalized Energy relative error cannot be properly computed as the core losses are unknown. Setting 'true_core_loss=1'.
# Normalized Energy relative error cannot be properly computed as the core losses are unknown. Setting 'true_core_loss=1'.
# 	MSE :   15.07 (A/m)²
# 	WCE :   40.53 A/m
# 	MSE :   14.14 (A/m)²
# 	WCE :   41.33 A/m
# 	MSE :   10.97 (A/m)²
# 	WCE :   49.50 A/m
# Normalized Energy relative error cannot be properly computed as the core losses are unknown. Setting 'true_core_loss=1'.
# Normalized Energy relative error cannot be properly computed as the core losses are unknown. Setting 'true_core_loss=1'.
# Normalized Energy relative error cannot be properly computed as the core losses are unknown. Setting 'true_core_loss=1'.
# 	MSE :   28.13 (A/m)²
# 	WCE :  115.85 A/m
# 	MSE :   24.37 (A/m)²
# 	WCE :  114.85 A/m
# 	MSE :   14.92 (A/m)²
# 	WCE :   72.60 A/m
# Normalized Energy relative error cannot be properly computed as the core losses are unknown. Setting 'true_core_loss=1'.
# Normalized Energy relative error cannot be properly computed as the core losses are unknown. Setting 'true_core_loss=1'.
# Normalized Energy relative error cannot be properly computed as the core losses are unknown. Setting 'true_core_loss=1'.
# 	MSE :   17.94 (A/m)²
# 	WCE :   46.26 A/m
# 	MSE :   16.06 (A/m)²
# 	WCE :   47.02 A/m
# 	MSE :   11.59 (A/m)²
# 	WCE :   38.99 A/m
# Normalized Energy relative error cannot be properly computed as the core losses are unknown. Setting 'true_core_loss=1'.
# Normalized Energy relative error cannot be properly computed as the core losses are unknown. Setting 'true_core_loss=1'.
# Normalized Energy relative error cannot be properly computed as the core losses are unknown. Setting 'true_core_loss=1'.
# 	MSE :   44.79 (A/m)²
# 	WCE :  132.16 A/m
# 	MSE :   41.11 (A/m)²
# 	WCE :  132.15 A/m
# 	MSE :   30.13 (A/m)²
# 	WCE :  122.65 A/m
# Normalized Energy relative error cannot be properly computed as the core losses are unknown. Setting 'true_core_loss=1'.
# Normalized Energy relative error cannot be properly computed as the core losses are unknown. Setting 'true_core_loss=1'.
# Normalized Energy relative error cannot be properly computed as the core losses are unknown. Setting 'true_core_loss=1'.
# 	MSE :   11.24 (A/m)²
# 	WCE :   57.14 A/m
# 	MSE :   10.17 (A/m)²
# 	WCE :   54.43 A/m
# 	MSE :    7.10 (A/m)²
# 	WCE :   47.17 A/m
# Normalized Energy relative error cannot be properly computed as the core losses are unknown. Setting 'true_core_loss=1'.
# Normalized Energy relative error cannot be properly computed as the core losses are unknown. Setting 'true_core_loss=1'.
# Normalized Energy relative error cannot be properly computed as the core losses are unknown. Setting 'true_core_loss=1'.
# 	MSE :   18.72 (A/m)²
# 	WCE :   68.51 A/m
# 	MSE :   16.53 (A/m)²
# 	WCE :   68.13 A/m
# 	MSE :   11.49 (A/m)²
# 	WCE :   37.20 A/m
# Normalized Energy relative error cannot be properly computed as the core losses are unknown. Setting 'true_core_loss=1'.
# Normalized Energy relative error cannot be properly computed as the core losses are unknown. Setting 'true_core_loss=1'.
# Normalized Energy relative error cannot be properly computed as the core losses are unknown. Setting 'true_core_loss=1'.
# 	MSE :   10.91 (A/m)²
# 	WCE :   57.64 A/m
# 	MSE :    9.65 (A/m)²
# 	WCE :   43.85 A/m
# 	MSE :    6.18 (A/m)²
# 	WCE :   41.64 A/m
# Normalized Energy relative error cannot be properly computed as the core losses are unknown. Setting 'true_core_loss=1'.
# Normalized Energy relative error cannot be properly computed as the core losses are unknown. Setting 'true_core_loss=1'.
# Normalized Energy relative error cannot be properly computed as the core losses are unknown. Setting 'true_core_loss=1'.
# 	MSE :   17.53 (A/m)²
# 	WCE :  102.01 A/m
# 	MSE :   16.43 (A/m)²
# 	WCE :   95.23 A/m
# 	MSE :   10.62 (A/m)²
# 	WCE :   80.99 A/m
# Normalized Energy relative error cannot be properly computed as the core losses are unknown. Setting 'true_core_loss=1'.
# Normalized Energy relative error cannot be properly computed as the core losses are unknown. Setting 'true_core_loss=1'.
# Normalized Energy relative error cannot be properly computed as the core losses are unknown. Setting 'true_core_loss=1'.
# 	MSE :   40.67 (A/m)²
# 	WCE :  105.36 A/m
# 	MSE :   39.69 (A/m)²
# 	WCE :  103.46 A/m
# 	MSE :   33.18 (A/m)²
# 	WCE :   84.13 A/m
# Normalized Energy relative error cannot be properly computed as the core losses are unknown. Setting 'true_core_loss=1'.
# Normalized Energy relative error cannot be properly computed as the core losses are unknown. Setting 'true_core_loss=1'.
# Normalized Energy relative error cannot be properly computed as the core losses are unknown. Setting 'true_core_loss=1'.
# 	MSE :   16.79 (A/m)²
# 	WCE :   61.36 A/m
# 	MSE :   14.94 (A/m)²
# 	WCE :   57.33 A/m
# 	MSE :   10.26 (A/m)²
# 	WCE :   50.90 A/m
# Normalized Energy relative error cannot be properly computed as the core losses are unknown. Setting 'true_core_loss=1'.
# Normalized Energy relative error cannot be properly computed as the core losses are unknown. Setting 'true_core_loss=1'.
# Normalized Energy relative error cannot be properly computed as the core losses are unknown. Setting 'true_core_loss=1'.
# 	MSE :   47.42 (A/m)²
# 	WCE :  143.55 A/m
# 	MSE :   44.40 (A/m)²
# 	WCE :  143.57 A/m
# 	MSE :   30.71 (A/m)²
# 	WCE :  129.00 A/m
# Normalized Energy relative error cannot be properly computed as the core losses are unknown. Setting 'true_core_loss=1'.
# Normalized Energy relative error cannot be properly computed as the core losses are unknown. Setting 'true_core_loss=1'.
# Normalized Energy relative error cannot be properly computed as the core losses are unknown. Setting 'true_core_loss=1'.
# 	MSE :   30.64 (A/m)²
# 	WCE :  106.02 A/m
# 	MSE :   28.03 (A/m)²
# 	WCE :  105.01 A/m
# 	MSE :   19.10 (A/m)²
# 	WCE :   87.28 A/m
# Normalized Energy relative error cannot be properly computed as the core losses are unknown. Setting 'true_core_loss=1'.
# Normalized Energy relative error cannot be properly computed as the core losses are unknown. Setting 'true_core_loss=1'.
# Normalized Energy relative error cannot be properly computed as the core losses are unknown. Setting 'true_core_loss=1'.
# 	MSE :   49.22 (A/m)²
# 	WCE :  143.71 A/m
# 	MSE :   46.04 (A/m)²
# 	WCE :  143.62 A/m
# 	MSE :   31.98 (A/m)²
# 	WCE :  127.84 A/m
# Normalized Energy relative error cannot be properly computed as the core losses are unknown. Setting 'true_core_loss=1'.
# Normalized Energy relative error cannot be properly computed as the core losses are unknown. Setting 'true_core_loss=1'.
# Normalized Energy relative error cannot be properly computed as the core losses are unknown. Setting 'true_core_loss=1'.
# 	MSE :   12.13 (A/m)²
# 	WCE :   54.46 A/m
# 	MSE :   11.20 (A/m)²
# 	WCE :   54.46 A/m
# 	MSE :    8.81 (A/m)²
# 	WCE :   52.32 A/m
# Normalized Energy relative error cannot be properly computed as the core losses are unknown. Setting 'true_core_loss=1'.
# Normalized Energy relative error cannot be properly computed as the core losses are unknown. Setting 'true_core_loss=1'.
# Normalized Energy relative error cannot be properly computed as the core losses are unknown. Setting 'true_core_loss=1'.
# 	MSE :   15.02 (A/m)²
# 	WCE :   45.90 A/m
# 	MSE :   13.77 (A/m)²
# 	WCE :   46.45 A/m
# 	MSE :    9.41 (A/m)²
# 	WCE :   40.57 A/m
# Normalized Energy relative error cannot be properly computed as the core losses are unknown. Setting 'true_core_loss=1'.
# Normalized Energy relative error cannot be properly computed as the core losses are unknown. Setting 'true_core_loss=1'.
# Normalized Energy relative error cannot be properly computed as the core losses are unknown. Setting 'true_core_loss=1'.
# 	MSE :   12.14 (A/m)²
# 	WCE :   34.63 A/m
# 	MSE :   11.20 (A/m)²
# 	WCE :   34.63 A/m
# 	MSE :    8.51 (A/m)²
# 	WCE :   35.13 A/m
# Normalized Energy relative error cannot be properly computed as the core losses are unknown. Setting 'true_core_loss=1'.
# Normalized Energy relative error cannot be properly computed as the core losses are unknown. Setting 'true_core_loss=1'.
# Normalized Energy relative error cannot be properly computed as the core losses are unknown. Setting 'true_core_loss=1'.
# 	MSE :    8.47 (A/m)²
# 	WCE :  110.60 A/m
# 	MSE :    6.83 (A/m)²
# 	WCE :   32.21 A/m
# 	MSE :    4.54 (A/m)²
# 	WCE :   29.56 A/m
# Normalized Energy relative error cannot be properly computed as the core losses are unknown. Setting 'true_core_loss=1'.
# Normalized Energy relative error cannot be properly computed as the core losses are unknown. Setting 'true_core_loss=1'.
# Normalized Energy relative error cannot be properly computed as the core losses are unknown. Setting 'true_core_loss=1'.
# 	MSE :   12.04 (A/m)²
# 	WCE :   35.10 A/m
# 	MSE :   11.40 (A/m)²
# 	WCE :   35.10 A/m
# 	MSE :    8.14 (A/m)²
# 	WCE :   36.35 A/m
# Normalized Energy relative error cannot be properly computed as the core losses are unknown. Setting 'true_core_loss=1'.
# Normalized Energy relative error cannot be properly computed as the core losses are unknown. Setting 'true_core_loss=1'.
# Normalized Energy relative error cannot be properly computed as the core losses are unknown. Setting 'true_core_loss=1'.
# 	MSE :   20.56 (A/m)²
# 	WCE :   61.27 A/m
# 	MSE :   18.35 (A/m)²
# 	WCE :   61.24 A/m
# 	MSE :   12.25 (A/m)²
# 	WCE :   46.69 A/m
# Normalized Energy relative error cannot be properly computed as the core losses are unknown. Setting 'true_core_loss=1'.
# Normalized Energy relative error cannot be properly computed as the core losses are unknown. Setting 'true_core_loss=1'.
# Normalized Energy relative error cannot be properly computed as the core losses are unknown. Setting 'true_core_loss=1'.
# 	MSE :   26.72 (A/m)²
# 	WCE :  102.81 A/m
# 	MSE :   24.04 (A/m)²
# 	WCE :  101.45 A/m
# 	MSE :   15.72 (A/m)²
# 	WCE :   79.08 A/m
# Normalized Energy relative error cannot be properly computed as the core losses are unknown. Setting 'true_core_loss=1'.
# Normalized Energy relative error cannot be properly computed as the core losses are unknown. Setting 'true_core_loss=1'.
# Normalized Energy relative error cannot be properly computed as the core losses are unknown. Setting 'true_core_loss=1'.
# 	MSE :   31.42 (A/m)²
# 	WCE :  113.06 A/m
# 	MSE :   28.16 (A/m)²
# 	WCE :  110.77 A/m
# 	MSE :   20.69 (A/m)²
# 	WCE :   89.97 A/m
# Normalized Energy relative error cannot be properly computed as the core losses are unknown. Setting 'true_core_loss=1'.
# Normalized Energy relative error cannot be properly computed as the core losses are unknown. Setting 'true_core_loss=1'.
# Normalized Energy relative error cannot be properly computed as the core losses are unknown. Setting 'true_core_loss=1'.
# 	MSE :   17.33 (A/m)²
# 	WCE :   82.74 A/m
# 	MSE :   15.65 (A/m)²
# 	WCE :   80.67 A/m
# 	MSE :   10.51 (A/m)²
# 	WCE :   64.87 A/m
# Normalized Energy relative error cannot be properly computed as the core losses are unknown. Setting 'true_core_loss=1'.
# Normalized Energy relative error cannot be properly computed as the core losses are unknown. Setting 'true_core_loss=1'.
# Normalized Energy relative error cannot be properly computed as the core losses are unknown. Setting 'true_core_loss=1'.
# 	MSE :   50.62 (A/m)²
# 	WCE :  142.69 A/m
# 	MSE :   46.64 (A/m)²
# 	WCE :  142.61 A/m
# 	MSE :   32.48 (A/m)²
# 	WCE :  127.43 A/m
# Normalized Energy relative error cannot be properly computed as the core losses are unknown. Setting 'true_core_loss=1'.
# Normalized Energy relative error cannot be properly computed as the core losses are unknown. Setting 'true_core_loss=1'.
# Normalized Energy relative error cannot be properly computed as the core losses are unknown. Setting 'true_core_loss=1'.
# 	MSE :   23.49 (A/m)²
# 	WCE :   96.79 A/m
# 	MSE :   20.90 (A/m)²
# 	WCE :   89.15 A/m
# 	MSE :   12.47 (A/m)²
# 	WCE :   64.61 A/m
# Normalized Energy relative error cannot be properly computed as the core losses are unknown. Setting 'true_core_loss=1'.
# Normalized Energy relative error cannot be properly computed as the core losses are unknown. Setting 'true_core_loss=1'.
# Normalized Energy relative error cannot be properly computed as the core losses are unknown. Setting 'true_core_loss=1'.
# 	MSE :   16.40 (A/m)²
# 	WCE :   50.78 A/m
# 	MSE :   14.26 (A/m)²
# 	WCE :   49.41 A/m
# 	MSE :    9.01 (A/m)²
# 	WCE :   57.85 A/m
# Normalized Energy relative error cannot be properly computed as the core losses are unknown. Setting 'true_core_loss=1'.
# Normalized Energy relative error cannot be properly computed as the core losses are unknown. Setting 'true_core_loss=1'.
# Normalized Energy relative error cannot be properly computed as the core losses are unknown. Setting 'true_core_loss=1'.
# 	MSE :   17.08 (A/m)²
# 	WCE :   50.79 A/m
# 	MSE :   16.18 (A/m)²
# 	WCE :   50.79 A/m
# 	MSE :   12.88 (A/m)²
# 	WCE :   43.16 A/m
# Normalized Energy relative error cannot be properly computed as the core losses are unknown. Setting 'true_core_loss=1'.
# Normalized Energy relative error cannot be properly computed as the core losses are unknown. Setting 'true_core_loss=1'.
# Normalized Energy relative error cannot be properly computed as the core losses are unknown. Setting 'true_core_loss=1'.
# 	MSE :   34.16 (A/m)²
# 	WCE :   61.50 A/m
# 	MSE :   30.81 (A/m)²
# 	WCE :   61.50 A/m
# 	MSE :   20.54 (A/m)²
# 	WCE :   60.55 A/m
# Normalized Energy relative error cannot be properly computed as the core losses are unknown. Setting 'true_core_loss=1'.
# Normalized Energy relative error cannot be properly computed as the core losses are unknown. Setting 'true_core_loss=1'.
# Normalized Energy relative error cannot be properly computed as the core losses are unknown. Setting 'true_core_loss=1'.
# 	MSE :   15.67 (A/m)²
# 	WCE :   42.76 A/m
# 	MSE :   13.99 (A/m)²
# 	WCE :   39.35 A/m
# 	MSE :    9.70 (A/m)²
# 	WCE :   38.40 A/m
# Found model file at '/home/oliverjs@uni-paderborn.de/mc_2/magnet-challenge-2/data/models/B_GRU6_final-comp-reduced_00713de0_seed4.eqx'. Loading model..
# Found model file at '/home/oliverjs@uni-paderborn.de/mc_2/magnet-challenge-2/data/models/B_GRU32_final-comp-reduced_de405193_seed4.eqx'. Loading model..
# Found model file at '/home/oliverjs@uni-paderborn.de/mc_2/magnet-challenge-2/data/models/B_GRU8_final-comp-reduced_79099b6c_seed4.eqx'. Loading model..
# Found model file at '/home/oliverjs@uni-paderborn.de/mc_2/magnet-challenge-2/data/models/B_GRU6_final-comp-reduced_555bdfcd_seed3.eqx'. Loading model..
# Found model file at '/home/oliverjs@uni-paderborn.de/mc_2/magnet-challenge-2/data/models/B_GRU10_final-comp-reduced_96c79ca5_seed3.eqx'. Loading model..
# Found model file at '/home/oliverjs@uni-paderborn.de/mc_2/magnet-challenge-2/data/models/B_GRU2_final-comp-reduced_c0440310_seed2.eqx'. Loading model..
# Found model file at '/home/oliverjs@uni-paderborn.de/mc_2/magnet-challenge-2/data/models/B_GRU2_final-comp-reduced_f89c16f8_seed4.eqx'. Loading model..
# Found model file at '/home/oliverjs@uni-paderborn.de/mc_2/magnet-challenge-2/data/models/B_GRU4_final-comp-reduced_868eb75a_seed4.eqx'. Loading model..
# Found model file at '/home/oliverjs@uni-paderborn.de/mc_2/magnet-challenge-2/data/models/B_GRU32_final-comp-reduced_6bd4bc13_seed2.eqx'. Loading model..
# Found model file at '/home/oliverjs@uni-paderborn.de/mc_2/magnet-challenge-2/data/models/B_GRU4_final-comp-reduced_93984182_seed2.eqx'. Loading model..
# Found model file at '/home/oliverjs@uni-paderborn.de/mc_2/magnet-challenge-2/data/models/B_GRU10_final-comp-reduced_96c79ca5_seed1.eqx'. Loading model..
# Found model file at '/home/oliverjs@uni-paderborn.de/mc_2/magnet-challenge-2/data/models/B_GRU10_final-comp-reduced_b07266f5_seed5.eqx'. Loading model..
# Found model file at '/home/oliverjs@uni-paderborn.de/mc_2/magnet-challenge-2/data/models/B_GRU4_final-comp-reduced_93984182_seed3.eqx'. Loading model..
# Found model file at '/home/oliverjs@uni-paderborn.de/mc_2/magnet-challenge-2/data/models/B_GRU16_final-comp-reduced_109d9989_seed2.eqx'. Loading model..
# Found model file at '/home/oliverjs@uni-paderborn.de/mc_2/magnet-challenge-2/data/models/B_GRU2_final-comp-reduced_c0440310_seed3.eqx'. Loading model..
# Found model file at '/home/oliverjs@uni-paderborn.de/mc_2/magnet-challenge-2/data/models/B_GRU6_final-comp-reduced_555bdfcd_seed1.eqx'. Loading model..
# Found model file at '/home/oliverjs@uni-paderborn.de/mc_2/magnet-challenge-2/data/models/B_GRU16_final-comp-reduced_27369a81_seed4.eqx'. Loading model..
# Found model file at '/home/oliverjs@uni-paderborn.de/mc_2/magnet-challenge-2/data/models/B_GRU16_final-comp-reduced_109d9989_seed3.eqx'. Loading model..
# Found model file at '/home/oliverjs@uni-paderborn.de/mc_2/magnet-challenge-2/data/models/B_GRU6_final-comp-reduced_555bdfcd_seed2.eqx'. Loading model..
# Found model file at '/home/oliverjs@uni-paderborn.de/mc_2/magnet-challenge-2/data/models/B_GRU32_final-comp-reduced_6bd4bc13_seed3.eqx'. Loading model..
# Found model file at '/home/oliverjs@uni-paderborn.de/mc_2/magnet-challenge-2/data/models/B_GRU16_final-comp-reduced_109d9989_seed1.eqx'. Loading model..
# Found model file at '/home/oliverjs@uni-paderborn.de/mc_2/magnet-challenge-2/data/models/B_GRU4_final-comp-reduced_868eb75a_seed5.eqx'. Loading model..
# Found model file at '/home/oliverjs@uni-paderborn.de/mc_2/magnet-challenge-2/data/models/B_GRU4_final-comp-reduced_93984182_seed1.eqx'. Loading model..
# Found model file at '/home/oliverjs@uni-paderborn.de/mc_2/magnet-challenge-2/data/models/B_GRU6_final-comp-reduced_00713de0_seed5.eqx'. Loading model..
# Found model file at '/home/oliverjs@uni-paderborn.de/mc_2/magnet-challenge-2/data/models/B_GRU10_final-comp-reduced_96c79ca5_seed2.eqx'. Loading model..
# Found model file at '/home/oliverjs@uni-paderborn.de/mc_2/magnet-challenge-2/data/models/B_GRU32_final-comp-reduced_6bd4bc13_seed1.eqx'. Loading model..
# Found model file at '/home/oliverjs@uni-paderborn.de/mc_2/magnet-challenge-2/data/models/B_GRU8_final-comp-reduced_79099b6c_seed5.eqx'. Loading model..
# Found model file at '/home/oliverjs@uni-paderborn.de/mc_2/magnet-challenge-2/data/models/B_GRU2_final-comp-reduced_c0440310_seed1.eqx'. Loading model..
# Found model file at '/home/oliverjs@uni-paderborn.de/mc_2/magnet-challenge-2/data/models/B_GRU32_final-comp-reduced_de405193_seed5.eqx'. Loading model..
# Found model file at '/home/oliverjs@uni-paderborn.de/mc_2/magnet-challenge-2/data/models/B_GRU10_final-comp-reduced_b07266f5_seed4.eqx'. Loading model..
# Found model file at '/home/oliverjs@uni-paderborn.de/mc_2/magnet-challenge-2/data/models/B_GRU8_final-comp-reduced_1976601c_seed3.eqx'. Loading model..
# Found model file at '/home/oliverjs@uni-paderborn.de/mc_2/magnet-challenge-2/data/models/B_GRU8_final-comp-reduced_1976601c_seed2.eqx'. Loading model..
# Found model file at '/home/oliverjs@uni-paderborn.de/mc_2/magnet-challenge-2/data/models/B_GRU2_final-comp-reduced_f89c16f8_seed5.eqx'. Loading model..
# Found model file at '/home/oliverjs@uni-paderborn.de/mc_2/magnet-challenge-2/data/models/B_GRU16_final-comp-reduced_27369a81_seed5.eqx'. Loading model..
# Found model file at '/home/oliverjs@uni-paderborn.de/mc_2/magnet-challenge-2/data/models/B_GRU8_final-comp-reduced_1976601c_seed1.eqx'. Loading model..
# Loading data for B: 100%|██████████| 15/15 [00:04<00:00,  3.56it/s]
# No data found for frequency index 6, skipping frequency.
# No data found for frequency index 7, skipping frequency.
# Normalized Energy relative error cannot be properly computed as the core losses are unknown. Setting 'true_core_loss=1'.
# Normalized Energy relative error cannot be properly computed as the core losses are unknown. Setting 'true_core_loss=1'.
# Normalized Energy relative error cannot be properly computed as the core losses are unknown. Setting 'true_core_loss=1'.
# 	MSE :    2.37 (A/m)²
# 	WCE :   81.89 A/m
# 	MSE :    2.14 (A/m)²
# 	WCE :   81.84 A/m
# 	MSE :    1.47 (A/m)²
# 	WCE :   69.73 A/m
# Normalized Energy relative error cannot be properly computed as the core losses are unknown. Setting 'true_core_loss=1'.
# Normalized Energy relative error cannot be properly computed as the core losses are unknown. Setting 'true_core_loss=1'.
# Normalized Energy relative error cannot be properly computed as the core losses are unknown. Setting 'true_core_loss=1'.
# 	MSE :    1.52 (A/m)²
# 	WCE :   59.56 A/m
# 	MSE :    3.51 (A/m)²
# 	WCE :  130.03 A/m
# 	MSE :    1.05 (A/m)²
# 	WCE :   93.84 A/m
# Normalized Energy relative error cannot be properly computed as the core losses are unknown. Setting 'true_core_loss=1'.
# Normalized Energy relative error cannot be properly computed as the core losses are unknown. Setting 'true_core_loss=1'.
# Normalized Energy relative error cannot be properly computed as the core losses are unknown. Setting 'true_core_loss=1'.
# 	MSE :    2.16 (A/m)²
# 	WCE :   98.65 A/m
# 	MSE :    1.95 (A/m)²
# 	WCE :   98.65 A/m
# 	MSE :    1.08 (A/m)²
# 	WCE :   67.83 A/m
# Normalized Energy relative error cannot be properly computed as the core losses are unknown. Setting 'true_core_loss=1'.
# Normalized Energy relative error cannot be properly computed as the core losses are unknown. Setting 'true_core_loss=1'.
# Normalized Energy relative error cannot be properly computed as the core losses are unknown. Setting 'true_core_loss=1'.
# 	MSE :    3.83 (A/m)²
# 	WCE :  130.37 A/m
# 	MSE :    3.77 (A/m)²
# 	WCE :  129.50 A/m
# 	MSE :    2.11 (A/m)²
# 	WCE :   99.44 A/m
# Normalized Energy relative error cannot be properly computed as the core losses are unknown. Setting 'true_core_loss=1'.
# Normalized Energy relative error cannot be properly computed as the core losses are unknown. Setting 'true_core_loss=1'.
# Normalized Energy relative error cannot be properly computed as the core losses are unknown. Setting 'true_core_loss=1'.
# 	MSE :    1.84 (A/m)²
# 	WCE :   92.19 A/m
# 	MSE :    1.75 (A/m)²
# 	WCE :   92.19 A/m
# 	MSE :    0.95 (A/m)²
# 	WCE :   67.22 A/m
# Normalized Energy relative error cannot be properly computed as the core losses are unknown. Setting 'true_core_loss=1'.
# Normalized Energy relative error cannot be properly computed as the core losses are unknown. Setting 'true_core_loss=1'.
# Normalized Energy relative error cannot be properly computed as the core losses are unknown. Setting 'true_core_loss=1'.
# 	MSE :    6.58 (A/m)²
# 	WCE :  131.71 A/m
# 	MSE :    6.00 (A/m)²
# 	WCE :  125.79 A/m
# 	MSE :    4.16 (A/m)²
# 	WCE :  112.61 A/m
# Normalized Energy relative error cannot be properly computed as the core losses are unknown. Setting 'true_core_loss=1'.
# Normalized Energy relative error cannot be properly computed as the core losses are unknown. Setting 'true_core_loss=1'.
# Normalized Energy relative error cannot be properly computed as the core losses are unknown. Setting 'true_core_loss=1'.
# 	MSE :    8.94 (A/m)²
# 	WCE :  162.76 A/m
# 	MSE :    8.10 (A/m)²
# 	WCE :  162.80 A/m
# 	MSE :    4.85 (A/m)²
# 	WCE :  124.23 A/m
# Normalized Energy relative error cannot be properly computed as the core losses are unknown. Setting 'true_core_loss=1'.
# Normalized Energy relative error cannot be properly computed as the core losses are unknown. Setting 'true_core_loss=1'.
# Normalized Energy relative error cannot be properly computed as the core losses are unknown. Setting 'true_core_loss=1'.
# 	MSE :    4.93 (A/m)²
# 	WCE :  125.26 A/m
# 	MSE :    4.47 (A/m)²
# 	WCE :  124.55 A/m
# 	MSE :    2.46 (A/m)²
# 	WCE :   91.92 A/m
# Normalized Energy relative error cannot be properly computed as the core losses are unknown. Setting 'true_core_loss=1'.
# Normalized Energy relative error cannot be properly computed as the core losses are unknown. Setting 'true_core_loss=1'.
# Normalized Energy relative error cannot be properly computed as the core losses are unknown. Setting 'true_core_loss=1'.
# 	MSE :    1.44 (A/m)²
# 	WCE :   77.70 A/m
# 	MSE :    1.20 (A/m)²
# 	WCE :   77.50 A/m
# 	MSE :    0.40 (A/m)²
# 	WCE :   48.97 A/m
# Normalized Energy relative error cannot be properly computed as the core losses are unknown. Setting 'true_core_loss=1'.
# Normalized Energy relative error cannot be properly computed as the core losses are unknown. Setting 'true_core_loss=1'.
# Normalized Energy relative error cannot be properly computed as the core losses are unknown. Setting 'true_core_loss=1'.
# 	MSE :    3.33 (A/m)²
# 	WCE :   97.84 A/m
# 	MSE :    3.02 (A/m)²
# 	WCE :   95.73 A/m
# 	MSE :    2.08 (A/m)²
# 	WCE :   84.16 A/m
# Normalized Energy relative error cannot be properly computed as the core losses are unknown. Setting 'true_core_loss=1'.
# Normalized Energy relative error cannot be properly computed as the core losses are unknown. Setting 'true_core_loss=1'.
# Normalized Energy relative error cannot be properly computed as the core losses are unknown. Setting 'true_core_loss=1'.
# 	MSE :    2.12 (A/m)²
# 	WCE :   70.76 A/m
# 	MSE :    1.80 (A/m)²
# 	WCE :   70.65 A/m
# 	MSE :    0.88 (A/m)²
# 	WCE :   40.55 A/m
# Normalized Energy relative error cannot be properly computed as the core losses are unknown. Setting 'true_core_loss=1'.
# Normalized Energy relative error cannot be properly computed as the core losses are unknown. Setting 'true_core_loss=1'.
# Normalized Energy relative error cannot be properly computed as the core losses are unknown. Setting 'true_core_loss=1'.
# 	MSE :    1.95 (A/m)²
# 	WCE :   78.32 A/m
# 	MSE :    1.64 (A/m)²
# 	WCE :   78.52 A/m
# 	MSE :    0.80 (A/m)²
# 	WCE :   61.72 A/m
# Normalized Energy relative error cannot be properly computed as the core losses are unknown. Setting 'true_core_loss=1'.
# Normalized Energy relative error cannot be properly computed as the core losses are unknown. Setting 'true_core_loss=1'.
# Normalized Energy relative error cannot be properly computed as the core losses are unknown. Setting 'true_core_loss=1'.
# 	MSE :    3.18 (A/m)²
# 	WCE :  120.25 A/m
# 	MSE :    2.88 (A/m)²
# 	WCE :  120.26 A/m
# 	MSE :    2.06 (A/m)²
# 	WCE :   80.78 A/m
# Normalized Energy relative error cannot be properly computed as the core losses are unknown. Setting 'true_core_loss=1'.
# Normalized Energy relative error cannot be properly computed as the core losses are unknown. Setting 'true_core_loss=1'.
# Normalized Energy relative error cannot be properly computed as the core losses are unknown. Setting 'true_core_loss=1'.
# 	MSE :    2.52 (A/m)²
# 	WCE :   90.36 A/m
# 	MSE :    2.32 (A/m)²
# 	WCE :   80.88 A/m
# 	MSE :    1.23 (A/m)²
# 	WCE :   62.64 A/m
# Normalized Energy relative error cannot be properly computed as the core losses are unknown. Setting 'true_core_loss=1'.
# Normalized Energy relative error cannot be properly computed as the core losses are unknown. Setting 'true_core_loss=1'.
# Normalized Energy relative error cannot be properly computed as the core losses are unknown. Setting 'true_core_loss=1'.
# 	MSE :    7.85 (A/m)²
# 	WCE :  158.37 A/m
# 	MSE :   17.01 (A/m)²
# 	WCE :  180.94 A/m
# 	MSE :    6.92 (A/m)²
# 	WCE :  110.17 A/m
# Normalized Energy relative error cannot be properly computed as the core losses are unknown. Setting 'true_core_loss=1'.
# Normalized Energy relative error cannot be properly computed as the core losses are unknown. Setting 'true_core_loss=1'.
# Normalized Energy relative error cannot be properly computed as the core losses are unknown. Setting 'true_core_loss=1'.
# 	MSE :    2.41 (A/m)²
# 	WCE :   90.28 A/m
# 	MSE :    2.21 (A/m)²
# 	WCE :   90.31 A/m
# 	MSE :    1.26 (A/m)²
# 	WCE :   67.83 A/m
# Normalized Energy relative error cannot be properly computed as the core losses are unknown. Setting 'true_core_loss=1'.
# Normalized Energy relative error cannot be properly computed as the core losses are unknown. Setting 'true_core_loss=1'.
# Normalized Energy relative error cannot be properly computed as the core losses are unknown. Setting 'true_core_loss=1'.
# 	MSE :    1.84 (A/m)²
# 	WCE :   79.00 A/m
# 	MSE :    1.61 (A/m)²
# 	WCE :   79.02 A/m
# 	MSE :    0.89 (A/m)²
# 	WCE :   63.55 A/m
# Normalized Energy relative error cannot be properly computed as the core losses are unknown. Setting 'true_core_loss=1'.
# Normalized Energy relative error cannot be properly computed as the core losses are unknown. Setting 'true_core_loss=1'.
# Normalized Energy relative error cannot be properly computed as the core losses are unknown. Setting 'true_core_loss=1'.
# 	MSE :    1.85 (A/m)²
# 	WCE :   91.43 A/m
# 	MSE :    1.58 (A/m)²
# 	WCE :   88.77 A/m
# 	MSE :    0.71 (A/m)²
# 	WCE :   43.53 A/m
# Normalized Energy relative error cannot be properly computed as the core losses are unknown. Setting 'true_core_loss=1'.
# Normalized Energy relative error cannot be properly computed as the core losses are unknown. Setting 'true_core_loss=1'.
# Normalized Energy relative error cannot be properly computed as the core losses are unknown. Setting 'true_core_loss=1'.
# 	MSE :    2.72 (A/m)²
# 	WCE :  106.14 A/m
# 	MSE :    2.67 (A/m)²
# 	WCE :  106.14 A/m
# 	MSE :    1.77 (A/m)²
# 	WCE :   89.09 A/m
# Normalized Energy relative error cannot be properly computed as the core losses are unknown. Setting 'true_core_loss=1'.
# Normalized Energy relative error cannot be properly computed as the core losses are unknown. Setting 'true_core_loss=1'.
# Normalized Energy relative error cannot be properly computed as the core losses are unknown. Setting 'true_core_loss=1'.
# 	MSE :    1.70 (A/m)²
# 	WCE :   94.93 A/m
# 	MSE :    1.58 (A/m)²
# 	WCE :   93.72 A/m
# 	MSE :    0.52 (A/m)²
# 	WCE :   37.59 A/m
# Normalized Energy relative error cannot be properly computed as the core losses are unknown. Setting 'true_core_loss=1'.
# Normalized Energy relative error cannot be properly computed as the core losses are unknown. Setting 'true_core_loss=1'.
# Normalized Energy relative error cannot be properly computed as the core losses are unknown. Setting 'true_core_loss=1'.
# 	MSE :    1.41 (A/m)²
# 	WCE :   80.88 A/m
# 	MSE :    1.18 (A/m)²
# 	WCE :   80.60 A/m
# 	MSE :    0.49 (A/m)²
# 	WCE :   39.60 A/m
# Normalized Energy relative error cannot be properly computed as the core losses are unknown. Setting 'true_core_loss=1'.
# Normalized Energy relative error cannot be properly computed as the core losses are unknown. Setting 'true_core_loss=1'.
# Normalized Energy relative error cannot be properly computed as the core losses are unknown. Setting 'true_core_loss=1'.
# 	MSE :    3.62 (A/m)²
# 	WCE :  136.79 A/m
# 	MSE :    3.34 (A/m)²
# 	WCE :  136.80 A/m
# 	MSE :    1.80 (A/m)²
# 	WCE :   92.93 A/m
# Normalized Energy relative error cannot be properly computed as the core losses are unknown. Setting 'true_core_loss=1'.
# Normalized Energy relative error cannot be properly computed as the core losses are unknown. Setting 'true_core_loss=1'.
# Normalized Energy relative error cannot be properly computed as the core losses are unknown. Setting 'true_core_loss=1'.
# 	MSE :    3.00 (A/m)²
# 	WCE :  101.25 A/m
# 	MSE :    2.56 (A/m)²
# 	WCE :   97.62 A/m
# 	MSE :    1.13 (A/m)²
# 	WCE :   43.15 A/m
# Normalized Energy relative error cannot be properly computed as the core losses are unknown. Setting 'true_core_loss=1'.
# Normalized Energy relative error cannot be properly computed as the core losses are unknown. Setting 'true_core_loss=1'.
# Normalized Energy relative error cannot be properly computed as the core losses are unknown. Setting 'true_core_loss=1'.
# 	MSE :    3.16 (A/m)²
# 	WCE :   85.93 A/m
# 	MSE :    2.22 (A/m)²
# 	WCE :   85.93 A/m
# 	MSE :    1.39 (A/m)²
# 	WCE :   60.00 A/m
# Normalized Energy relative error cannot be properly computed as the core losses are unknown. Setting 'true_core_loss=1'.
# Normalized Energy relative error cannot be properly computed as the core losses are unknown. Setting 'true_core_loss=1'.
# Normalized Energy relative error cannot be properly computed as the core losses are unknown. Setting 'true_core_loss=1'.
# 	MSE :    1.81 (A/m)²
# 	WCE :   80.50 A/m
# 	MSE :    1.68 (A/m)²
# 	WCE :   80.71 A/m
# 	MSE :    0.84 (A/m)²
# 	WCE :   65.82 A/m
# Normalized Energy relative error cannot be properly computed as the core losses are unknown. Setting 'true_core_loss=1'.
# Normalized Energy relative error cannot be properly computed as the core losses are unknown. Setting 'true_core_loss=1'.
# Normalized Energy relative error cannot be properly computed as the core losses are unknown. Setting 'true_core_loss=1'.
# 	MSE :    1.48 (A/m)²
# 	WCE :   73.36 A/m
# 	MSE :    1.23 (A/m)²
# 	WCE :   73.14 A/m
# 	MSE :    0.50 (A/m)²
# 	WCE :   41.21 A/m
# Normalized Energy relative error cannot be properly computed as the core losses are unknown. Setting 'true_core_loss=1'.
# Normalized Energy relative error cannot be properly computed as the core losses are unknown. Setting 'true_core_loss=1'.
# Normalized Energy relative error cannot be properly computed as the core losses are unknown. Setting 'true_core_loss=1'.
# 	MSE :    2.00 (A/m)²
# 	WCE :   74.57 A/m
# 	MSE :    2.28 (A/m)²
# 	WCE :  132.60 A/m
# 	MSE :    3.26 (A/m)²
# 	WCE :  117.06 A/m
# Normalized Energy relative error cannot be properly computed as the core losses are unknown. Setting 'true_core_loss=1'.
# Normalized Energy relative error cannot be properly computed as the core losses are unknown. Setting 'true_core_loss=1'.
# Normalized Energy relative error cannot be properly computed as the core losses are unknown. Setting 'true_core_loss=1'.
# 	MSE :   11.91 (A/m)²
# 	WCE :  171.74 A/m
# 	MSE :   10.58 (A/m)²
# 	WCE :  146.49 A/m
# 	MSE :    6.01 (A/m)²
# 	WCE :  138.04 A/m
# Normalized Energy relative error cannot be properly computed as the core losses are unknown. Setting 'true_core_loss=1'.
# Normalized Energy relative error cannot be properly computed as the core losses are unknown. Setting 'true_core_loss=1'.
# Normalized Energy relative error cannot be properly computed as the core losses are unknown. Setting 'true_core_loss=1'.
# 	MSE :    1.42 (A/m)²
# 	WCE :   78.33 A/m
# 	MSE :    1.38 (A/m)²
# 	WCE :   79.58 A/m
# 	MSE :    0.41 (A/m)²
# 	WCE :   37.24 A/m
# Normalized Energy relative error cannot be properly computed as the core losses are unknown. Setting 'true_core_loss=1'.
# Normalized Energy relative error cannot be properly computed as the core losses are unknown. Setting 'true_core_loss=1'.
# Normalized Energy relative error cannot be properly computed as the core losses are unknown. Setting 'true_core_loss=1'.
# 	MSE :    1.95 (A/m)²
# 	WCE :   87.96 A/m
# 	MSE :    1.78 (A/m)²
# 	WCE :   88.61 A/m
# 	MSE :    0.80 (A/m)²
# 	WCE :   59.40 A/m
# Normalized Energy relative error cannot be properly computed as the core losses are unknown. Setting 'true_core_loss=1'.
# Normalized Energy relative error cannot be properly computed as the core losses are unknown. Setting 'true_core_loss=1'.
# Normalized Energy relative error cannot be properly computed as the core losses are unknown. Setting 'true_core_loss=1'.
# 	MSE :    2.01 (A/m)²
# 	WCE :   83.79 A/m
# 	MSE :    1.77 (A/m)²
# 	WCE :   83.79 A/m
# 	MSE :    1.21 (A/m)²
# 	WCE :   57.01 A/m
# Normalized Energy relative error cannot be properly computed as the core losses are unknown. Setting 'true_core_loss=1'.
# Normalized Energy relative error cannot be properly computed as the core losses are unknown. Setting 'true_core_loss=1'.
# Normalized Energy relative error cannot be properly computed as the core losses are unknown. Setting 'true_core_loss=1'.
# 	MSE :    2.31 (A/m)²
# 	WCE :  101.15 A/m
# 	MSE :    2.02 (A/m)²
# 	WCE :  102.10 A/m
# 	MSE :    1.35 (A/m)²
# 	WCE :   62.87 A/m
# Normalized Energy relative error cannot be properly computed as the core losses are unknown. Setting 'true_core_loss=1'.
# Normalized Energy relative error cannot be properly computed as the core losses are unknown. Setting 'true_core_loss=1'.
# Normalized Energy relative error cannot be properly computed as the core losses are unknown. Setting 'true_core_loss=1'.
# 	MSE :    8.41 (A/m)²
# 	WCE :  148.97 A/m
# 	MSE :    7.39 (A/m)²
# 	WCE :  136.08 A/m
# 	MSE :    4.36 (A/m)²
# 	WCE :  120.63 A/m
# Normalized Energy relative error cannot be properly computed as the core losses are unknown. Setting 'true_core_loss=1'.
# Normalized Energy relative error cannot be properly computed as the core losses are unknown. Setting 'true_core_loss=1'.
# Normalized Energy relative error cannot be properly computed as the core losses are unknown. Setting 'true_core_loss=1'.
# 	MSE :    1.63 (A/m)²
# 	WCE :   83.88 A/m
# 	MSE :    1.41 (A/m)²
# 	WCE :   83.87 A/m
# 	MSE :    0.60 (A/m)²
# 	WCE :   60.84 A/m
# Normalized Energy relative error cannot be properly computed as the core losses are unknown. Setting 'true_core_loss=1'.
# Normalized Energy relative error cannot be properly computed as the core losses are unknown. Setting 'true_core_loss=1'.
# Normalized Energy relative error cannot be properly computed as the core losses are unknown. Setting 'true_core_loss=1'.
# 	MSE :    2.25 (A/m)²
# 	WCE :   85.64 A/m
# 	MSE :    2.04 (A/m)²
# 	WCE :   85.64 A/m
# 	MSE :    1.27 (A/m)²
# 	WCE :   60.33 A/m
# Found model file at '/home/oliverjs@uni-paderborn.de/mc_2/magnet-challenge-2/data/models/C_GRU4_final-comp-reduced_da0a9659_seed4.eqx'. Loading model..
# Found model file at '/home/oliverjs@uni-paderborn.de/mc_2/magnet-challenge-2/data/models/C_GRU4_final-comp-reduced_da0a9659_seed5.eqx'. Loading model..
# Found model file at '/home/oliverjs@uni-paderborn.de/mc_2/magnet-challenge-2/data/models/C_GRU6_final-comp-reduced_0518bb0a_seed4.eqx'. Loading model..
# Found model file at '/home/oliverjs@uni-paderborn.de/mc_2/magnet-challenge-2/data/models/C_GRU6_final-comp-reduced_0518bb0a_seed5.eqx'. Loading model..
# Found model file at '/home/oliverjs@uni-paderborn.de/mc_2/magnet-challenge-2/data/models/C_GRU4_final-comp-reduced_10e73620_seed2.eqx'. Loading model..
# Found model file at '/home/oliverjs@uni-paderborn.de/mc_2/magnet-challenge-2/data/models/C_GRU32_final-comp-reduced_438412a5_seed3.eqx'. Loading model..
# Found model file at '/home/oliverjs@uni-paderborn.de/mc_2/magnet-challenge-2/data/models/C_GRU6_final-comp-reduced_7409273e_seed3.eqx'. Loading model..
# Found model file at '/home/oliverjs@uni-paderborn.de/mc_2/magnet-challenge-2/data/models/C_GRU32_final-comp-reduced_438412a5_seed1.eqx'. Loading model..
# Found model file at '/home/oliverjs@uni-paderborn.de/mc_2/magnet-challenge-2/data/models/C_GRU16_final-comp-reduced_192cb37a_seed4.eqx'. Loading model..
# Found model file at '/home/oliverjs@uni-paderborn.de/mc_2/magnet-challenge-2/data/models/C_GRU8_final-comp-reduced_c6c1668c_seed3.eqx'. Loading model..
# Found model file at '/home/oliverjs@uni-paderborn.de/mc_2/magnet-challenge-2/data/models/C_GRU16_final-comp-reduced_bd97474d_seed2.eqx'. Loading model..
# Found model file at '/home/oliverjs@uni-paderborn.de/mc_2/magnet-challenge-2/data/models/C_GRU2_final-comp-reduced_b1015b51_seed5.eqx'. Loading model..
# Found model file at '/home/oliverjs@uni-paderborn.de/mc_2/magnet-challenge-2/data/models/C_GRU6_final-comp-reduced_7409273e_seed2.eqx'. Loading model..
# Found model file at '/home/oliverjs@uni-paderborn.de/mc_2/magnet-challenge-2/data/models/C_GRU32_final-comp-reduced_61216567_seed4.eqx'. Loading model..
# Found model file at '/home/oliverjs@uni-paderborn.de/mc_2/magnet-challenge-2/data/models/C_GRU2_final-comp-reduced_b1015b51_seed4.eqx'. Loading model..
# Found model file at '/home/oliverjs@uni-paderborn.de/mc_2/magnet-challenge-2/data/models/C_GRU10_final-comp-reduced_5c9a08f9_seed5.eqx'. Loading model..
# Found model file at '/home/oliverjs@uni-paderborn.de/mc_2/magnet-challenge-2/data/models/C_GRU6_final-comp-reduced_7409273e_seed1.eqx'. Loading model..
# Found model file at '/home/oliverjs@uni-paderborn.de/mc_2/magnet-challenge-2/data/models/C_GRU8_final-comp-reduced_c6c1668c_seed2.eqx'. Loading model..
# Found model file at '/home/oliverjs@uni-paderborn.de/mc_2/magnet-challenge-2/data/models/C_GRU2_final-comp-reduced_d6a11473_seed3.eqx'. Loading model..
# Found model file at '/home/oliverjs@uni-paderborn.de/mc_2/magnet-challenge-2/data/models/C_GRU2_final-comp-reduced_d6a11473_seed1.eqx'. Loading model..
# ...
# Normalized Energy relative error cannot be properly computed as the core losses are unknown. Setting 'true_core_loss=1'.
# Normalized Energy relative error cannot be properly computed as the core losses are unknown. Setting 'true_core_loss=1'.
# 	MSE :    0.96 (A/m)²
# 	WCE :  180.49 A/m
# 	MSE :    0.92 (A/m)²
# 	WCE :  180.49 A/m
# 	MSE :    1.19 (A/m)²
# 	WCE :  180.55 A/m
# Normalized Energy relative error cannot be properly computed as the core losses are unknown. Setting 'true_core_loss=1'.
# Normalized Energy relative error cannot be properly computed as the core losses are unknown. Setting 'true_core_loss=1'.
# Normalized Energy relative error cannot be properly computed as the core losses are unknown. Setting 'true_core_loss=1'.
# 	MSE :    0.61 (A/m)²
# 	WCE :  185.64 A/m
# 	MSE :    0.66 (A/m)²
# 	WCE :  185.64 A/m
# 	MSE :    1.17 (A/m)²
# 	WCE :  185.66 A/m
# Normalized Energy relative error cannot be properly computed as the core losses are unknown. Setting 'true_core_loss=1'.
# Normalized Energy relative error cannot be properly computed as the core losses are unknown. Setting 'true_core_loss=1'.
# Normalized Energy relative error cannot be properly computed as the core losses are unknown. Setting 'true_core_loss=1'.
# 	MSE :    1.40 (A/m)²
# 	WCE :  203.24 A/m
# 	MSE :    1.40 (A/m)²
# 	WCE :  203.23 A/m
# 	MSE :    1.59 (A/m)²
# 	WCE :  201.65 A/m
# Normalized Energy relative error cannot be properly computed as the core losses are unknown. Setting 'true_core_loss=1'.
# Normalized Energy relative error cannot be properly computed as the core losses are unknown. Setting 'true_core_loss=1'.
# Normalized Energy relative error cannot be properly computed as the core losses are unknown. Setting 'true_core_loss=1'.
# 	MSE :    2.24 (A/m)²
# 	WCE :  223.64 A/m
# 	MSE :    2.22 (A/m)²
# 	WCE :  223.64 A/m
# 	MSE :    2.23 (A/m)²
# 	WCE :  221.83 A/m
# Normalized Energy relative error cannot be properly computed as the core losses are unknown. Setting 'true_core_loss=1'.
# Normalized Energy relative error cannot be properly computed as the core losses are unknown. Setting 'true_core_loss=1'.
# Normalized Energy relative error cannot be properly computed as the core losses are unknown. Setting 'true_core_loss=1'.
# 	MSE :    0.61 (A/m)²
# 	WCE :  179.84 A/m
# 	MSE :    0.68 (A/m)²
# 	WCE :  179.84 A/m
# 	MSE :    1.20 (A/m)²
# 	WCE :  180.20 A/m
# Normalized Energy relative error cannot be properly computed as the core losses are unknown. Setting 'true_core_loss=1'.
# Normalized Energy relative error cannot be properly computed as the core losses are unknown. Setting 'true_core_loss=1'.
# Normalized Energy relative error cannot be properly computed as the core losses are unknown. Setting 'true_core_loss=1'.
# 	MSE :    0.72 (A/m)²
# 	WCE :  167.23 A/m
# 	MSE :    0.72 (A/m)²
# 	WCE :  167.23 A/m
# 	MSE :    0.99 (A/m)²
# 	WCE :  167.29 A/m
# Normalized Energy relative error cannot be properly computed as the core losses are unknown. Setting 'true_core_loss=1'.
# Normalized Energy relative error cannot be properly computed as the core losses are unknown. Setting 'true_core_loss=1'.
# Normalized Energy relative error cannot be properly computed as the core losses are unknown. Setting 'true_core_loss=1'.
# 	MSE :    5.60 (A/m)²
# 	WCE :  247.55 A/m
# 	MSE :    5.62 (A/m)²
# 	WCE :  247.56 A/m
# 	MSE :    4.26 (A/m)²
# 	WCE :  234.33 A/m
# Normalized Energy relative error cannot be properly computed as the core losses are unknown. Setting 'true_core_loss=1'.
# Normalized Energy relative error cannot be properly computed as the core losses are unknown. Setting 'true_core_loss=1'.
# Normalized Energy relative error cannot be properly computed as the core losses are unknown. Setting 'true_core_loss=1'.
# 	MSE :    0.38 (A/m)²
# 	WCE :  141.39 A/m
# 	MSE :    0.38 (A/m)²
# 	WCE :  141.39 A/m
# 	MSE :    0.60 (A/m)²
# 	WCE :  141.38 A/m
# Normalized Energy relative error cannot be properly computed as the core losses are unknown. Setting 'true_core_loss=1'.
# Normalized Energy relative error cannot be properly computed as the core losses are unknown. Setting 'true_core_loss=1'.
# Normalized Energy relative error cannot be properly computed as the core losses are unknown. Setting 'true_core_loss=1'.
# 	MSE :    2.32 (A/m)²
# 	WCE :  204.95 A/m
# 	MSE :    2.12 (A/m)²
# 	WCE :  197.89 A/m
# 	MSE :    2.09 (A/m)²
# 	WCE :  197.27 A/m
# Normalized Energy relative error cannot be properly computed as the core losses are unknown. Setting 'true_core_loss=1'.
# Normalized Energy relative error cannot be properly computed as the core losses are unknown. Setting 'true_core_loss=1'.
# Normalized Energy relative error cannot be properly computed as the core losses are unknown. Setting 'true_core_loss=1'.
# 	MSE :    1.27 (A/m)²
# 	WCE :  202.50 A/m
# 	MSE :    1.24 (A/m)²
# 	WCE :  202.50 A/m
# 	MSE :    1.57 (A/m)²
# 	WCE :  201.30 A/m
# Normalized Energy relative error cannot be properly computed as the core losses are unknown. Setting 'true_core_loss=1'.
# Normalized Energy relative error cannot be properly computed as the core losses are unknown. Setting 'true_core_loss=1'.
# Normalized Energy relative error cannot be properly computed as the core losses are unknown. Setting 'true_core_loss=1'.
# 	MSE :    5.92 (A/m)²
# 	WCE :  249.06 A/m
# 	MSE :    5.83 (A/m)²
# 	WCE :  249.10 A/m
# 	MSE :    4.13 (A/m)²
# 	WCE :  240.83 A/m
# Normalized Energy relative error cannot be properly computed as the core losses are unknown. Setting 'true_core_loss=1'.
# Normalized Energy relative error cannot be properly computed as the core losses are unknown. Setting 'true_core_loss=1'.
# Normalized Energy relative error cannot be properly computed as the core losses are unknown. Setting 'true_core_loss=1'.
# 	MSE :    0.73 (A/m)²
# 	WCE :  171.28 A/m
# 	MSE :    0.75 (A/m)²
# 	WCE :  166.26 A/m
# 	MSE :    1.06 (A/m)²
# 	WCE :  170.26 A/m
# Normalized Energy relative error cannot be properly computed as the core losses are unknown. Setting 'true_core_loss=1'.
# Normalized Energy relative error cannot be properly computed as the core losses are unknown. Setting 'true_core_loss=1'.
# Normalized Energy relative error cannot be properly computed as the core losses are unknown. Setting 'true_core_loss=1'.
# 	MSE :    1.58 (A/m)²
# 	WCE :  222.15 A/m
# 	MSE :    1.66 (A/m)²
# 	WCE :  222.15 A/m
# 	MSE :    2.15 (A/m)²
# 	WCE :  222.00 A/m
# Normalized Energy relative error cannot be properly computed as the core losses are unknown. Setting 'true_core_loss=1'.
# Normalized Energy relative error cannot be properly computed as the core losses are unknown. Setting 'true_core_loss=1'.
# Normalized Energy relative error cannot be properly computed as the core losses are unknown. Setting 'true_core_loss=1'.
# 	MSE :    0.31 (A/m)²
# 	WCE :  120.44 A/m
# 	MSE :    0.29 (A/m)²
# 	WCE :  120.44 A/m
# 	MSE :    0.45 (A/m)²
# 	WCE :  124.34 A/m
# Normalized Energy relative error cannot be properly computed as the core losses are unknown. Setting 'true_core_loss=1'.
# Normalized Energy relative error cannot be properly computed as the core losses are unknown. Setting 'true_core_loss=1'.
# Normalized Energy relative error cannot be properly computed as the core losses are unknown. Setting 'true_core_loss=1'.
# 	MSE :    0.46 (A/m)²
# 	WCE :  128.84 A/m
# 	MSE :    0.43 (A/m)²
# 	WCE :  127.27 A/m
# 	MSE :    0.50 (A/m)²
# 	WCE :  127.37 A/m
# Normalized Energy relative error cannot be properly computed as the core losses are unknown. Setting 'true_core_loss=1'.
# Normalized Energy relative error cannot be properly computed as the core losses are unknown. Setting 'true_core_loss=1'.
# Normalized Energy relative error cannot be properly computed as the core losses are unknown. Setting 'true_core_loss=1'.
# 	MSE :    0.32 (A/m)²
# 	WCE :  130.17 A/m
# 	MSE :    0.31 (A/m)²
# 	WCE :  130.17 A/m
# 	MSE :    0.49 (A/m)²
# 	WCE :  130.55 A/m
# Normalized Energy relative error cannot be properly computed as the core losses are unknown. Setting 'true_core_loss=1'.
# Normalized Energy relative error cannot be properly computed as the core losses are unknown. Setting 'true_core_loss=1'.
# Normalized Energy relative error cannot be properly computed as the core losses are unknown. Setting 'true_core_loss=1'.
# 	MSE :    1.00 (A/m)²
# 	WCE :  182.65 A/m
# 	MSE :    0.98 (A/m)²
# 	WCE :  182.65 A/m
# 	MSE :    1.28 (A/m)²
# 	WCE :  184.76 A/m
# Normalized Energy relative error cannot be properly computed as the core losses are unknown. Setting 'true_core_loss=1'.
# Normalized Energy relative error cannot be properly computed as the core losses are unknown. Setting 'true_core_loss=1'.
# Normalized Energy relative error cannot be properly computed as the core losses are unknown. Setting 'true_core_loss=1'.
# 	MSE :    0.79 (A/m)²
# 	WCE :  170.87 A/m
# 	MSE :    0.75 (A/m)²
# 	WCE :  170.87 A/m
# 	MSE :    1.00 (A/m)²
# 	WCE :  171.58 A/m
# Normalized Energy relative error cannot be properly computed as the core losses are unknown. Setting 'true_core_loss=1'.
# Normalized Energy relative error cannot be properly computed as the core losses are unknown. Setting 'true_core_loss=1'.
# Normalized Energy relative error cannot be properly computed as the core losses are unknown. Setting 'true_core_loss=1'.
# 	MSE :    0.86 (A/m)²
# 	WCE :  172.38 A/m
# 	MSE :    0.82 (A/m)²
# 	WCE :  164.78 A/m
# 	MSE :    1.46 (A/m)²
# 	WCE :  157.01 A/m
# Normalized Energy relative error cannot be properly computed as the core losses are unknown. Setting 'true_core_loss=1'.
# Normalized Energy relative error cannot be properly computed as the core losses are unknown. Setting 'true_core_loss=1'.
# Normalized Energy relative error cannot be properly computed as the core losses are unknown. Setting 'true_core_loss=1'.
# 	MSE :    0.57 (A/m)²
# 	WCE :  154.89 A/m
# 	MSE :    0.55 (A/m)²
# 	WCE :  154.89 A/m
# 	MSE :    0.81 (A/m)²
# 	WCE :  161.81 A/m
# Normalized Energy relative error cannot be properly computed as the core losses are unknown. Setting 'true_core_loss=1'.
# Normalized Energy relative error cannot be properly computed as the core losses are unknown. Setting 'true_core_loss=1'.
# Normalized Energy relative error cannot be properly computed as the core losses are unknown. Setting 'true_core_loss=1'.
# 	MSE :    0.90 (A/m)²
# 	WCE :  182.84 A/m
# 	MSE :    0.88 (A/m)²
# 	WCE :  166.15 A/m
# 	MSE :    1.09 (A/m)²
# 	WCE :  166.12 A/m
# Normalized Energy relative error cannot be properly computed as the core losses are unknown. Setting 'true_core_loss=1'.
# Normalized Energy relative error cannot be properly computed as the core losses are unknown. Setting 'true_core_loss=1'.
# Normalized Energy relative error cannot be properly computed as the core losses are unknown. Setting 'true_core_loss=1'.
# 	MSE :    5.01 (A/m)²
# 	WCE :  245.72 A/m
# 	MSE :    5.14 (A/m)²
# 	WCE :  245.72 A/m
# 	MSE :    4.12 (A/m)²
# 	WCE :  242.11 A/m
# Normalized Energy relative error cannot be properly computed as the core losses are unknown. Setting 'true_core_loss=1'.
# Normalized Energy relative error cannot be properly computed as the core losses are unknown. Setting 'true_core_loss=1'.
# Normalized Energy relative error cannot be properly computed as the core losses are unknown. Setting 'true_core_loss=1'.
# 	MSE :    1.07 (A/m)²
# 	WCE :  194.43 A/m
# 	MSE :    1.04 (A/m)²
# 	WCE :  194.43 A/m
# 	MSE :    1.46 (A/m)²
# 	WCE :  194.80 A/m
# Normalized Energy relative error cannot be properly computed as the core losses are unknown. Setting 'true_core_loss=1'.
# Normalized Energy relative error cannot be properly computed as the core losses are unknown. Setting 'true_core_loss=1'.
# Normalized Energy relative error cannot be properly computed as the core losses are unknown. Setting 'true_core_loss=1'.
# 	MSE :    1.34 (A/m)²
# 	WCE :  214.44 A/m
# 	MSE :    1.40 (A/m)²
# 	WCE :  214.44 A/m
# 	MSE :    2.14 (A/m)²
# 	WCE :  216.34 A/m
# Normalized Energy relative error cannot be properly computed as the core losses are unknown. Setting 'true_core_loss=1'.
# Normalized Energy relative error cannot be properly computed as the core losses are unknown. Setting 'true_core_loss=1'.
# Normalized Energy relative error cannot be properly computed as the core losses are unknown. Setting 'true_core_loss=1'.
# 	MSE :    5.58 (A/m)²
# 	WCE :  248.05 A/m
# 	MSE :    5.58 (A/m)²
# 	WCE :  248.05 A/m
# 	MSE :    4.29 (A/m)²
# 	WCE :  234.85 A/m
# Normalized Energy relative error cannot be properly computed as the core losses are unknown. Setting 'true_core_loss=1'.
# Normalized Energy relative error cannot be properly computed as the core losses are unknown. Setting 'true_core_loss=1'.
# Normalized Energy relative error cannot be properly computed as the core losses are unknown. Setting 'true_core_loss=1'.
# 	MSE :    0.32 (A/m)²
# 	WCE :  143.61 A/m
# 	MSE :    0.32 (A/m)²
# 	WCE :  143.60 A/m
# 	MSE :    0.54 (A/m)²
# 	WCE :  147.48 A/m
# Normalized Energy relative error cannot be properly computed as the core losses are unknown. Setting 'true_core_loss=1'.
# Normalized Energy relative error cannot be properly computed as the core losses are unknown. Setting 'true_core_loss=1'.
# Normalized Energy relative error cannot be properly computed as the core losses are unknown. Setting 'true_core_loss=1'.
# 	MSE :    1.02 (A/m)²
# 	WCE :  189.00 A/m
# 	MSE :    1.05 (A/m)²
# 	WCE :  189.00 A/m
# 	MSE :    1.49 (A/m)²
# 	WCE :  190.47 A/m
# Normalized Energy relative error cannot be properly computed as the core losses are unknown. Setting 'true_core_loss=1'.
# Normalized Energy relative error cannot be properly computed as the core losses are unknown. Setting 'true_core_loss=1'.
# Normalized Energy relative error cannot be properly computed as the core losses are unknown. Setting 'true_core_loss=1'.
# 	MSE :    2.12 (A/m)²
# 	WCE :  227.03 A/m
# 	MSE :    2.20 (A/m)²
# 	WCE :  227.03 A/m
# 	MSE :    2.35 (A/m)²
# 	WCE :  225.93 A/m
# Normalized Energy relative error cannot be properly computed as the core losses are unknown. Setting 'true_core_loss=1'.
# Normalized Energy relative error cannot be properly computed as the core losses are unknown. Setting 'true_core_loss=1'.
# Normalized Energy relative error cannot be properly computed as the core losses are unknown. Setting 'true_core_loss=1'.
# 	MSE :    1.37 (A/m)²
# 	WCE :  217.98 A/m
# 	MSE :    1.49 (A/m)²
# 	WCE :  217.98 A/m
# 	MSE :    2.10 (A/m)²
# 	WCE :  216.30 A/m
# Normalized Energy relative error cannot be properly computed as the core losses are unknown. Setting 'true_core_loss=1'.
# Normalized Energy relative error cannot be properly computed as the core losses are unknown. Setting 'true_core_loss=1'.
# Normalized Energy relative error cannot be properly computed as the core losses are unknown. Setting 'true_core_loss=1'.
# 	MSE :    1.71 (A/m)²
# 	WCE :  225.57 A/m
# 	MSE :    1.77 (A/m)²
# 	WCE :  225.57 A/m
# 	MSE :    2.17 (A/m)²
# 	WCE :  223.87 A/m
# Normalized Energy relative error cannot be properly computed as the core losses are unknown. Setting 'true_core_loss=1'.
# Normalized Energy relative error cannot be properly computed as the core losses are unknown. Setting 'true_core_loss=1'.
# Normalized Energy relative error cannot be properly computed as the core losses are unknown. Setting 'true_core_loss=1'.
# 	MSE :    0.42 (A/m)²
# 	WCE :  134.06 A/m
# 	MSE :    0.39 (A/m)²
# 	WCE :  134.06 A/m
# 	MSE :    0.59 (A/m)²
# 	WCE :  134.34 A/m
# Normalized Energy relative error cannot be properly computed as the core losses are unknown. Setting 'true_core_loss=1'.
# Normalized Energy relative error cannot be properly computed as the core losses are unknown. Setting 'true_core_loss=1'.
# Normalized Energy relative error cannot be properly computed as the core losses are unknown. Setting 'true_core_loss=1'.
# 	MSE :    0.32 (A/m)²
# 	WCE :  124.32 A/m
# 	MSE :    0.32 (A/m)²
# 	WCE :  124.32 A/m
# 	MSE :    0.47 (A/m)²
# 	WCE :  126.59 A/m
# Normalized Energy relative error cannot be properly computed as the core losses are unknown. Setting 'true_core_loss=1'.
# Normalized Energy relative error cannot be properly computed as the core losses are unknown. Setting 'true_core_loss=1'.
# Normalized Energy relative error cannot be properly computed as the core losses are unknown. Setting 'true_core_loss=1'.
# 	MSE :    5.82 (A/m)²
# 	WCE :  250.19 A/m
# 	MSE :    5.68 (A/m)²
# 	WCE :  250.19 A/m
# 	MSE :    4.29 (A/m)²
# 	WCE :  248.04 A/m

# %% [markdown]
# ## Plotting

# %%
scenarios_per_material={"A":list(FINAL_SCENARIOS_PER_MATERIAL["A"].keys()),
                        "B":list(FINAL_SCENARIOS_PER_MATERIAL["B"].keys()),
                        "C":list(FINAL_SCENARIOS_PER_MATERIAL["C"].keys()),
                        "D":list(FINAL_SCENARIOS_PER_MATERIAL["D"].keys()),
                        "E":list(FINAL_SCENARIOS_PER_MATERIAL["E"].keys())}

df= pd.read_pickle('results_pareto_front.pkl')

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib.lines import Line2D

def visualize_pareto_front_all_mats(df, scenarios_per_materials, metrics, scale_log=False, scale_log_x=False, sharex='col', sharey='row', chosen_param_size=-1):
    materials = sorted(df["material"].unique())
    num_rows = len(metrics) #len(scenarios_per_materials[materials[0]]) *
    num_cols = len(materials)
    sns.set_theme(style="whitegrid")
    
    fig, axs = plt.subplots(nrows=num_rows, ncols=num_cols, sharex=sharex,sharey=sharey,
                            figsize=(3.5 * num_cols, 4 * num_rows), squeeze=False)

    palette = sns.color_palette("deep")
    c_avg, c_95th = palette[0], palette[1]

    for mat_idx, material_name in enumerate(materials):
        scenarios = scenarios_per_materials[material_name]
        mat_df = df[df["material"] == material_name]
        for m_idx, metric in enumerate(metrics):
            row_idx = m_idx
            ax = axs[row_idx, mat_idx]
            if row_idx == 0: ax.set_title(material_name, fontweight='bold',fontsize=14)
            visualize_single_pareto_front_sns(
                mat_df, ax, scenarios, metric, 
                colors=(c_avg, c_95th),
                show_x_label=(row_idx == num_rows - 1),
                show_y_label=(mat_idx == 0),
                scale_log=scale_log, scale_log_x=scale_log_x,
                chosen_param_size=chosen_param_size
            )

    legend_elements = [
        Line2D([0], [0], marker='o', color='w', label='Average', markerfacecolor=c_avg, markersize=10, linestyle='None'),
        Line2D([0], [0], marker='^', color='w', label='95th Quantile', markerfacecolor=c_95th, markersize=10, linestyle='None')
    ]
    fig.legend(handles=legend_elements, loc='upper center', bbox_to_anchor=(0.5, 1.05), ncol=2, frameon=True, shadow=False,fontsize=14)
    fig.tight_layout()
    return fig, axs

def visualize_single_pareto_front_sns(df, ax, scenarios, metric, colors, show_x_label, show_y_label, scale_log, scale_log_x, chosen_param_size=-1):
    #df_plot = df[df["scenario"] == scenario].copy()
    df_plot = df[df["scenario"].isin(scenarios)].copy()
    df_agg = df_plot.groupby(["n_params", "material"])[[f"{metric}_avg", f"{metric}_95th"]].mean().reset_index()
    df_melted = df_agg.melt(
        id_vars=["n_params", "material"],
        value_vars=[f"{metric}_avg", f"{metric}_95th"],
        var_name="Type", value_name="Value"
    )
    for label, m, c in zip([f"{metric}_avg", f"{metric}_95th"], ["o", "^"], colors):
        
        sns.stripplot(
            data=df_melted[(df_melted["Type"] == label) & (df_melted["n_params"] != chosen_param_size)],
            x="n_params", y="Value",
            color=c, marker=m, alpha=1,
            size=8,
            jitter=0.05, 
            ax=ax, native_scale=True 
        )
        mask_highlight = (df_melted["Type"] == label) & (df_melted["n_params"] == chosen_param_size)
        highlight_df = df_melted[mask_highlight]
        if not highlight_df.empty:
            sns.stripplot(
            data=highlight_df,
            x="n_params", y="Value",
            edgecolor="lime",
            linewidth=1.5,
            color=c, marker=m, alpha=1,
            size=8,
            jitter=0.05, 
            ax=ax, native_scale=True 
        )
    
    if scale_log: 
        ax.set_yscale("log")
    if scale_log_x: 
        ax.set_xscale("log")
    unique_params = sorted(df_plot["n_params"].unique())
    ax.set_xticks(unique_params)
    ax.set_xticklabels(unique_params, rotation=45, ha='right', fontsize=12)
    if show_y_label:
        # label_map = {"sre": "Sequence relative error", "nere": "Normalized energy relative error"}
        # ax.set_ylabel(label_map.get(metric, metric),fontsize=14)
        label_map = {"sre": "Mean Seq. Rel. Error", "nere": "Mean Norm. Energy Rel. Error"}
        ax.set_ylabel(label_map.get(metric, metric), fontsize=14)
    else:
        ax.set_ylabel("",fontsize=14)

    if show_x_label:
        ax.set_xlabel("Model size",fontsize=14)
    else:
        ax.set_xlabel("")

# %%
fig,axs=visualize_pareto_front_all_mats(df,scenarios_per_material,metrics=["sre","nere"],scale_log=True,scale_log_x=True,sharey='row', sharex=True,chosen_param_size=325)

# %%
fig,axs=visualize_pareto_front_all_mats(df_all[df_all["material"]=="D"],scenarios_per_material,metrics=["sre"],scale_log=True,scale_log_x=True,sharey='row', sharex=True,chosen_param_size=325)
