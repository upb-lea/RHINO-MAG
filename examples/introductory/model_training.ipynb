# %% [markdown]
# # Model training:

# %%
# optional setup
# %load_ext autoreload
# %autoreload 2

import os
os.environ['CUDA_VISIBLE_DEVICES'] = '0'  # choose cuda-device
os.environ["XLA_PYTHON_CLIENT_PREALLOCATE"]="false"  # disable preallocation of memory

import jax
#jax.config.update("jax_platform_name", "cpu")  # optionally run on cpu

# %%
from rhmag.runners.rnn_training_jax import train_model_jax
from rhmag.utils.model_evaluation import get_exp_ids, reconstruct_model_from_file

# %% [markdown]
# ## Training function:
#
# More indepth descriptions of each parameter are given in the docstring for the function. Either look for the implementation in the source code (at `rhmag.runners.rnn_training_jax`) or press `shift+tab` while your caret is within the function name to show the docstring (at least in `jupyter-lab` and `jupyter-notebook`).

# %%
train_model_jax(
    material_names=["A"],  # perform training for material "A"
    model_types=["GRU4", "JA"],  # a training with all specified seeds is ran for all model types in the list
    seeds=[1, 2],  # a training is ran for each seed in the list
    exp_name="demonstration",
    loss_type="adapted_RMS",  # default loss function
    gpu_id=0,  # gpu at index 0
    epochs=10,  # very short for demonstration
    batch_size=512,
    tbptt_size=156,  # length of a sequence through which the loss is backpropagated
    past_size=28,  # how much of the sequence should be used for warmup
    time_shift=0,  # adds a feature, where the B trajectory is shifted by {time_shift} steps
    noise_on_data=0.0,  # adds noise to the B data in training
    tbptt_size_start=None,  # can be used to specify a pretraining phase, e.g., with shorter sequences
    dyn_avg_kernel_size=11,  # size of the kernel for the dynamic averaging (unused for the "reduced" feature set)
    disable_f64=True,  # if 'True' training is performed on f32 accuracy
    disable_features="reduce",  # One of (True, False, "reduce"), True uses no features, False uses all default features, "reduce" uses the dB/dt and d^2 B / dt^2 as features
    transform_H=False,  # flag whether a tanh transform of H should be utilized
    use_all_data=False,  # flag, whether all data should be used for training or if instead a train, eval, test split should be performed
)
# Out:
# 2026-03-31 16:14:51 | INFO : Starting experiments for material(s) 1 for 2 model type(s) and 2 seeds: ['GRU4', 'JA'], [1, 2]
# 2026-03-31 16:14:51 | INFO : === Starting experiments for Material: A ===
# 2026-03-31 16:14:51 | INFO : --- Starting experiments for Model Type: GRU4 ---
# INFO:2026-03-31 16:14:51,680:jax._src.xla_bridge:925: Unable to initialize backend 'rocm': module 'jaxlib.xla_extension' has no attribute 'GpuAllocatorConfig'
# 2026-03-31 16:14:51 | INFO : Unable to initialize backend 'rocm': module 'jaxlib.xla_extension' has no attribute 'GpuAllocatorConfig'
# INFO:2026-03-31 16:14:51,682:jax._src.xla_bridge:925: Unable to initialize backend 'tpu': INTERNAL: Failed to open libtpu.so: libtpu.so: cannot open shared object file: No such file or directory
# 2026-03-31 16:14:51 | INFO : Unable to initialize backend 'tpu': INTERNAL: Failed to open libtpu.so: libtpu.so: cannot open shared object file: No such file or directory
# Loading data for A: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 21/21 [00:06<00:00,  3.02it/s]
# 2026-03-31 16:15:05 | INFO : Training starting. Experiment ID is 'A_GRU4_demonstration_26dee33e_seed1'.
# 2026-03-31 16:15:05 | INFO : train size: 63, val size: 21, test size: 21
# 2026-03-31 16:15:07 | INFO : Test loss seed 1: 7.699741 A/m
# Seed 1:   0%|          | 0/10 [00:00<?, ?epoch/s]
# 2026-03-31 16:15:25 | INFO : Test loss seed 1: 3.197384 A/m
# 2026-03-31 16:15:25 | INFO : Training done. Proceeding with evaluation..
# 2026-03-31 16:16:19 | INFO : Evaluation done. Proceeding with storing experiment data..
# RNNwInterface(
#   model=GRU(
#     hidden_size=4,
#     cell=GRUCell(
#       weight_ih=f32[12,4],
#       weight_hh=f32[12,4],
#       bias=f32[12],
#       bias_n=f32[4],
#       input_size=4,
#       hidden_size=4,
#       use_bias=True
#     )
#   ),
#   normalizer=Normalizer(
#     B_max=0.468600869178772,
#     H_max=261.848388671875,
#     T_max=70,
#     norm_fe_max=[0.00948895514011383, 0.005385361611843109],
#     H_transform=<function <lambda>>,
#     H_inverse_transform=<function <lambda>>
#   ),
#   featurize=partial(<function featurize>, time_shift=0)
# )
# 2026-03-31 16:16:30 | INFO : Experiment with id 'A_GRU4_demonstration_26dee33e_seed1' finished successfully. Parameters, logs, evaluation metrics, and the model have been stored successfully.
# Loading data for A: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 21/21 [00:07<00:00,  2.96it/s]
# 2026-03-31 16:16:45 | INFO : Training starting. Experiment ID is 'A_GRU4_demonstration_26dee33e_seed2'.
# 2026-03-31 16:16:45 | INFO : train size: 63, val size: 21, test size: 21
# 2026-03-31 16:16:48 | INFO : Test loss seed 2: 3.331386 A/m
# Seed 2:   0%|          | 0/10 [00:00<?, ?epoch/s]
# 2026-03-31 16:17:04 | INFO : Test loss seed 2: 2.067909 A/m
# 2026-03-31 16:17:04 | INFO : Training done. Proceeding with evaluation..
# 2026-03-31 16:17:59 | INFO : Evaluation done. Proceeding with storing experiment data..
# RNNwInterface(
#   model=GRU(
#     hidden_size=4,
#     cell=GRUCell(
#       weight_ih=f32[12,4],
#       weight_hh=f32[12,4],
#       bias=f32[12],
#       bias_n=f32[4],
#       input_size=4,
#       hidden_size=4,
#       use_bias=True
#     )
#   ),
#   normalizer=Normalizer(
#     B_max=0.468600869178772,
#     H_max=261.848388671875,
#     T_max=70,
#     norm_fe_max=[0.00948895514011383, 0.005385361611843109],
#     H_transform=<function <lambda>>,
#     H_inverse_transform=<function <lambda>>
#   ),
#   featurize=partial(<function featurize>, time_shift=0)
# )
# 2026-03-31 16:18:11 | INFO : Experiment with id 'A_GRU4_demonstration_26dee33e_seed2' finished successfully. Parameters, logs, evaluation metrics, and the model have been stored successfully.
# 2026-03-31 16:18:12 | INFO : --- Starting experiments for Model Type: JA ---
# Loading data for A: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 21/21 [00:10<00:00,  2.02it/s]
# 2026-03-31 16:18:30 | INFO : Training starting. Experiment ID is 'A_JA_demonstration_08af2b5d_seed1'.
# 2026-03-31 16:18:30 | INFO : train size: 63, val size: 21, test size: 21
# 2026-03-31 16:18:32 | INFO : Test loss seed 1: 0.447387 A/m
# Seed 1:   0%|          | 0/10 [00:00<?, ?epoch/s]
# 2026-03-31 16:18:47 | INFO : Test loss seed 1: 0.443940 A/m
# 2026-03-31 16:18:47 | INFO : Training done. Proceeding with evaluation..
# 2026-03-31 16:19:34 | INFO : Evaluation done. Proceeding with storing experiment data..
# JAwInterface(
#   model=JAStatic(
#     Ms_param=f32[],
#     a_param=f32[],
#     alpha_param=f32[],
#     k_param=f32[],
#     c_param=f32[]
#   ),
#   normalizer=Normalizer(
#     B_max=0.468600869178772,
#     H_max=261.848388671875,
#     T_max=70,
#     norm_fe_max=[0.00948895514011383, 0.005385361611843109],
#     H_transform=<function <lambda>>,
#     H_inverse_transform=<function <lambda>>
#   ),
#   featurize=partial(<function featurize>, time_shift=0)
# )
# 2026-03-31 16:19:47 | INFO : Experiment with id 'A_JA_demonstration_08af2b5d_seed1' finished successfully. Parameters, logs, evaluation metrics, and the model have been stored successfully.
# Loading data for A: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 21/21 [00:09<00:00,  2.16it/s]
# 2026-03-31 16:20:04 | INFO : Training starting. Experiment ID is 'A_JA_demonstration_08af2b5d_seed2'.
# 2026-03-31 16:20:04 | INFO : train size: 63, val size: 21, test size: 21
# 2026-03-31 16:20:06 | INFO : Test loss seed 2: 0.448741 A/m
# Seed 2:   0%|          | 0/10 [00:00<?, ?epoch/s]
# 2026-03-31 16:20:20 | INFO : Test loss seed 2: 0.448338 A/m
# 2026-03-31 16:20:20 | INFO : Training done. Proceeding with evaluation..
# 2026-03-31 16:21:04 | INFO : Evaluation done. Proceeding with storing experiment data..
# JAwInterface(
#   model=JAStatic(
#     Ms_param=f32[],
#     a_param=f32[],
#     alpha_param=f32[],
#     k_param=f32[],
#     c_param=f32[]
#   ),
#   normalizer=Normalizer(
#     B_max=0.468600869178772,
#     H_max=261.848388671875,
#     T_max=70,
#     norm_fe_max=[0.00948895514011383, 0.005385361611843109],
#     H_transform=<function <lambda>>,
#     H_inverse_transform=<function <lambda>>
#   ),
#   featurize=partial(<function featurize>, time_shift=0)
# )
# 2026-03-31 16:21:15 | INFO : Experiment with id 'A_JA_demonstration_08af2b5d_seed2' finished successfully. Parameters, logs, evaluation metrics, and the model have been stored successfully.
# 2026-03-31 16:21:17 | INFO : All scheduled experiments completed.

# %% [markdown]
# this can also be run from the command line:
# - `python rhmag/runners/rnn_training_jax.py -h` shows all options
# - exemplary call: `python rhmag/runners/rnn_training_jax.py --material "A" --model_types "GRU4" "JA" --seeds 1 2 3 --loss_type "adapted_RMS"  --exp_name "demonstration" --gpu_id 0 -e 10 -b 512 -t 156 -p 28 --disable_f64`
# - Due to the amount of options it is generally easier to handle if you create a script where all parameters are already set (i.e., copy the cell above into a python script)

# %%
exp_ids = get_exp_ids(exp_name="demonstration")
exp_ids
# Out:
# ['A_GRU4_demonstration_075ced14_seed1',
#  'A_GRU4_demonstration_e1879564_seed1',
#  'E_MagnetizationGRU32_demonstration_d1ccf33d_seed1',
#  'A_JA_demonstration_7a265925_seed1',
#  'A_GRU4_demonstration_e1879564_seed3',
#  'A_JA_demonstration_beec08e8_seed3',
#  'A_JADirectParamGRU8_demonstration_3b3031f8_seed1',
#  'A_JA_demonstration_08af2b5d_seed1',
#  'A_JA_demonstration_3a3c5cf4_seed1',
#  'A_JAPinnWithGRU_demonstration_e7dcad51_seed1',
#  'A_GRU4_demonstration_26dee33e_seed1',
#  'A_GRU4_demonstration_b8a83189_seed1',
#  'E_GRUwLinearModel_demonstration_f5aac235_seed1',
#  'E_GRUwLinearModel32_demonstration_64971bd5_seed1',
#  'A_GRU4_demonstration_e1879564_seed2',
#  'A_JAPinnWithGRU_demonstration_5c22a6b9_seed1',
#  'A_JA_demonstration_7a265925_seed2',
#  'A_JA_demonstration_3a3c5cf4_seed2',
#  'E_GRUwLinearModel_demonstration_c961591a_seed1',
#  'A_GRU4_demonstration_67ccce69_seed2',
#  'A_GRU4_demonstration_1c80af77_seed1',
#  'A_JA_demonstration_beec08e8_seed2',
#  'A_JAWithGRU8_demonstration_6a0402f1_seed1',
#  'A_GRU4_demonstration_1c80af77_seed3',
#  'E_GRUwLinearModel_demonstration_0a8ae335_seed1',
#  'A_JA_demonstration_beec08e8_seed1',
#  'A_JA_demonstration_08af2b5d_seed2',
#  'A_JA_demonstration_3a3c5cf4_seed3',
#  'A_GRU4_demonstration_26dee33e_seed2',
#  'A_JAPinnWithGRU_demonstration_f4717289_seed1',
#  'A_GRU4_demonstration_67ccce69_seed3',
#  'A_GRU4_demonstration_67ccce69_seed1',
#  'A_JADirectParamGRU8_demonstration_80bbad10_seed1',
#  'A_GRU4_demonstration_1c80af77_seed2',
#  'E_GRUwLinearModel_demonstration_9ef3656f_seed1',
#  'A_GRU4_demonstration_075ced14_seed2']

# %%
model = reconstruct_model_from_file(exp_ids[-1])
model
# Out:
# Found model file at '/home/hvater@uni-paderborn.de/projects/magnet-challenge-2/data/models/A_GRU4_demonstration_075ced14_seed2.eqx'. Loading model..
# RNNwInterface(
#   model=GRU(
#     hidden_size=4,
#     cell=GRUCell(
#       weight_ih=f32[12,4],
#       weight_hh=f32[12,4],
#       bias=f32[12],
#       bias_n=f32[4],
#       input_size=4,
#       hidden_size=4,
#       use_bias=True
#     )
#   ),
#   normalizer=Normalizer(
#     B_max=0.468600869178772,
#     H_max=261.848388671875,
#     T_max=70,
#     norm_fe_max=[0.00948895514011383, 0.005385361611843109],
#     H_transform=<function <lambda>>,
#     H_inverse_transform=<function <lambda>>
#   ),
#   featurize=partial(<function featurize>, time_shift=0)
# )
